# %%
import torch
import torch.nn as nn
import torchvision.transforms.functional as func

from torchvision.models import resnet18

class ResNet18Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        resnet = resnet18(weights=None)
        self.stem = nn.Sequential(resnet.conv1, resnet.bn1, resnet.relu)
        self.pool = resnet.maxpool
        self.encoder1 = resnet.layer1
        self.encoder2 = resnet.layer2
        self.encoder3 = resnet.layer3
        self.encoder4 = resnet.layer4
    def forward(self, x):
        x0 = self.stem(x)
        x1 = self.encoder1(self.pool(x0))
        x2 = self.encoder2(x1)
        x3 = self.encoder3(x2)
        x4 = self.encoder4(x3)
        return x0, x1, x2, x3, x4


class DecoderBlock(nn.Module):
    def __init__(self, in_channels, skip_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)
        self.conv = nn.Sequential(
            nn.Conv2d(skip_channels + out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )

    def forward(self, x, skip):
        x = self.up(x)
        skip = func.center_crop(skip, [x.shape[2], x.shape[3]])
        x = torch.cat([x, skip], dim=1)
        return self.conv(x)

class ResNetUNet(nn.Module):
    def __init__(self, n_classes=1):
        super().__init__()
        self.encoder = ResNet18Encoder()

        self.decoder4 = DecoderBlock(512, 256, 256)
        self.decoder3 = DecoderBlock(256, 128, 128)
        self.decoder2 = DecoderBlock(128, 64, 64)
        self.decoder1 = DecoderBlock(64, 64, 32)

        self.final_conv = nn.Conv2d(32, n_classes, kernel_size=1)

    def forward(self, x):
        x0, x1, x2, x3, x4 = self.encoder(x)

        d4 = self.decoder4(x4, x3)
        d3 = self.decoder3(d4, x2)
        d2 = self.decoder2(d3, x1)
        d1 = self.decoder1(d2, x0)

        out = self.final_conv(d1)
        return out

# %%
from torch.utils.data import Dataset
import tifffile as tif
import random
from torchvision import transforms
import os

random.seed(42)

imageTransform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
maskTransform = transforms.Compose([transforms.ToTensor()])

class LandslideDataset(Dataset):
    def __init__(self, img_list, mask_list):
        self.img_list = img_list
        self.mask_list = mask_list
    
    def __len__(self):
        return len(self.img_list)
    
    def __getitem__(self, index):
        img_dir = self.img_list[index]
        mask_dir = self.mask_list[index]

        img = tif.imread(img_dir)
        mask = tif.imread(mask_dir)

        img = imageTransform(img)
        mask = (maskTransform(mask) > 0).float()

        return img, mask

path = "../../data/"
limit = 100
regions = [f for f in os.listdir(path) if (os.path.isdir(os.path.join(path, f)) and f != "study areas shp")]

regions_dict = dict()

for region in regions:
    dataset_dir = path + region
    image_dir = os.path.join(dataset_dir, "img")
    img_list = os.listdir(image_dir)

    all_images = sorted(os.path.join(image_dir, f) for f in img_list)

    if len(all_images) > limit:
        all_images = random.sample(all_images, limit)

    regions_dict[region] = all_images

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def getMetrics(TP, TN, FP, FN):
    precision = TP / (TP + FP + 1e-8)
    recall = TP / (TP + FN + 1e-8)
    f1 = 2 * precision * recall / (precision + recall + 1e-8)
        
    iou_1  = TP / (TP + FP + FN + 1e-8)
    iou_0 = TN / (TN + FP + FN + 1e-8)
    miou = (iou_0 + iou_1) / 2 
        
    oa = (TP + TN)/(TP + TN + FP + FN + 1e-8)
    
    return precision, recall, f1, iou_1, miou, oa

def dice_loss(pred, target, smooth=1.):
    pred = torch.sigmoid(pred)
    pred_flat = pred.view(-1)
    target_flat = target.view(-1)
    intersection = (pred_flat * target_flat).sum()
    return 1 - ((2. * intersection + smooth) / (pred_flat.sum() + target_flat.sum() + smooth))


### COMPUTE R (NEGATIVE PIXELS / POSITIVE PIXELS)
r = 4.5
pos_weight = torch.tensor([r]).to(device)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# %%
import torch.nn.functional as F

def train_model(model, optimizer, train_loader, val_loader, epochs, model_path, region_name, threshold=0.6):
    best_iou = 0.0
    patience = 10
    counter = 0

    print(f'region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa')

    for epoch in range(epochs):
        model.train()
        running_loss, n_samples = 0.0, 0

        for images, masks in train_loader:
            images = images.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True).float()

            optimizer.zero_grad(set_to_none=True)

            logits = model(images)
            if logits.shape[-2:] != masks.shape[-2:]:
                logits = F.interpolate(logits, size=masks.shape[-2:], mode="bilinear", align_corners=False)

            bce  = criterion(logits, masks)
            dice = dice_loss(logits, masks)
            loss = bce + dice

            loss.backward()
            optimizer.step()

            running_loss += loss.item() * masks.numel()
            n_samples += masks.numel()
        
        training_loss = running_loss / max(1, n_samples)

        model.eval()
        val_loss, val_num = 0.0, 0
        
        TP, FP, FN, TN = 0,0,0,0

        with torch.no_grad():
            for images, masks in val_loader:
                images = images.to(device, non_blocking=True)
                masks = masks.to(device, non_blocking=True).float()

                logits = model(images)
                if logits.shape[-2:] != masks.shape[-2:]:
                    logits = F.interpolate(logits, size=masks.shape[-2:], mode="bilinear", align_corners=False)

                bce  = criterion(logits, masks)
                dice = dice_loss(logits, masks)
                loss = bce + dice
                val_loss += loss.item()

                preds = torch.sigmoid(logits) > threshold

                preds_flat = preds.view(-1)
                mask_flat = masks.view(-1)

                TP += ((preds_flat == 1) & (mask_flat == 1)).sum().item()
                FP += ((preds_flat == 1) & (mask_flat == 0)).sum().item()
                FN += ((preds_flat == 0) & (mask_flat == 1)).sum().item()
                TN += ((preds_flat == 0) & (mask_flat == 0)).sum().item()
                
                val_num += 1
             
        precision, recall, f1, iou, miou, oa = getMetrics(TP, TN, FP, FN)

        print(f'{region_name}, {epoch+1}, {training_loss :.3f}, {val_loss / val_num :.3f}, {precision:.4f}, {recall:.4f}, {f1:.4f}, {iou:.4f}, {miou:.4f}, {oa:.4f}')

        if iou > best_iou:
            best_iou = iou
            counter = 0
            
            torch.save(model.state_dict(), model_path)
        elif iou != 0.0:
            counter += 1
            if counter >= patience:
                break

def test_model(model, test_loader, threshold=0.6):
    TP, FP, FN, TN = 0,0,0,0

    model.eval()

    with torch.no_grad():
        for images, masks in test_loader:
            images = images.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True).float()

            logits = model(images)
            if logits.shape[-2:] != masks.shape[-2:]:
                logits = F.interpolate(logits, size=masks.shape[-2:], mode="bilinear", align_corners=False)

            preds = torch.sigmoid(logits) > threshold
                    
            preds_flat = preds.view(-1)
            mask_flat = masks.view(-1)

            TP += ((preds_flat == 1) & (mask_flat == 1)).sum().item()
            FP += ((preds_flat == 1) & (mask_flat == 0)).sum().item()
            FN += ((preds_flat == 0) & (mask_flat == 1)).sum().item()
            TN += ((preds_flat == 0) & (mask_flat == 0)).sum().item()

    return getMetrics(TP, TN, FP, FN)

# %%
### SOURCE ONLY ###

from torch.utils.data import DataLoader
import torch.optim as optim
from sklearn.model_selection import train_test_split

batch_size = 16

output = "source_region,target_region,precision,recall,f1,iou,miou,oa"

for source_region in regions_dict:
    image_paths = regions_dict[source_region]
    mask_paths = [f.replace("img", "mask") for f in image_paths]

    train_img, val_img, train_mask, val_mask = train_test_split(
        image_paths, mask_paths, test_size=.2, random_state=42
    )

    train_dataset = LandslideDataset(train_img, train_mask)
    val_dataset = LandslideDataset(val_img, val_mask)

    trainLoader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=torch.cuda.is_available())
    valLoader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=torch.cuda.is_available())

    epochs = 40

    model = ResNetUNet()
    model.to(device)

    optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)

    model_path = "../../models/baseline/source_only/" + source_region + ".pth"

    train_model(model, optimizer, trainLoader, valLoader, epochs, model_path, source_region)

    model.load_state_dict(torch.load(model_path, map_location=device))

    for target_region in regions_dict:
        if target_region != source_region:
            image_paths = regions_dict[target_region]
            mask_paths = [f.replace("img", "mask") for f in image_paths]

            test_dataset = LandslideDataset(image_paths, mask_paths)
            testLoader = DataLoader(test_dataset, batch_size=batch_size,shuffle=False,num_workers=0, pin_memory=torch.cuda.is_available())

            precision, recall, f1, iou, miou, oa = test_model(model, testLoader)
            result = f'{source_region}, {target_region}, {precision:.4f}, {recall:.4f}, {f1:.4f}, {iou:.4f}, {miou:.4f}, {oa:.4f}'
            print(result)
            output += f'\n{result}'
    
with open("../../results/baseline/source_only.csv", "w") as f:
    f.write(output)
# Out:
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Hokkaido Iburi-Tobu, 1, 1.742, 1.677, 0.0000, 0.0000, 0.0000, 0.0000, 0.4686, 0.9372
# Hokkaido Iburi-Tobu, 2, 1.725, 1.675, 0.0000, 0.0000, 0.0000, 0.0000, 0.4686, 0.9372
# Hokkaido Iburi-Tobu, 3, 1.701, 1.667, 0.0000, 0.0000, 0.0000, 0.0000, 0.4686, 0.9372
# Hokkaido Iburi-Tobu, 4, 1.664, 1.650, 0.0000, 0.0000, 0.0000, 0.0000, 0.4686, 0.9372
# Hokkaido Iburi-Tobu, 5, 1.599, 1.605, 0.0000, 0.0000, 0.0000, 0.0000, 0.4686, 0.9372
# Hokkaido Iburi-Tobu, 6, 1.483, 1.443, 0.0000, 0.0000, 0.0000, 0.0000, 0.4686, 0.9372
# Hokkaido Iburi-Tobu, 7, 1.178, 3.793, 0.0000, 0.0000, 0.0000, 0.0000, 0.4686, 0.9372
# Hokkaido Iburi-Tobu, 8, 0.918, 2.084, 0.8047, 0.1864, 0.3027, 0.1784, 0.5619, 0.9460
# Hokkaido Iburi-Tobu, 9, 0.823, 1.484, 0.7539, 0.4988, 0.6004, 0.4290, 0.6929, 0.9583
# Hokkaido Iburi-Tobu, 10, 0.767, 0.938, 0.5709, 0.7726, 0.6566, 0.4888, 0.7177, 0.9492
# Hokkaido Iburi-Tobu, 11, 0.823, 1.102, 0.7087, 0.6472, 0.6765, 0.5112, 0.7353, 0.9611
# Hokkaido Iburi-Tobu, 12, 0.853, 1.115, 0.7533, 0.6097, 0.6739, 0.5082, 0.7348, 0.9629
# Hokkaido Iburi-Tobu, 13, 0.747, 0.851, 0.6230, 0.7475, 0.6796, 0.5147, 0.7341, 0.9557
# Hokkaido Iburi-Tobu, 14, 0.721, 0.878, 0.5564, 0.8203, 0.6631, 0.4960, 0.7204, 0.9476
# Hokkaido Iburi-Tobu, 15, 0.730, 0.824, 0.6018, 0.7990, 0.6865, 0.5227, 0.7372, 0.9542
# Hokkaido Iburi-Tobu, 16, 0.707, 0.801, 0.6320, 0.7407, 0.6820, 0.5175, 0.7360, 0.9566
# Hokkaido Iburi-Tobu, 17, 0.683, 0.772, 0.6420, 0.7548, 0.6938, 0.5312, 0.7436, 0.9582
# Hokkaido Iburi-Tobu, 18, 0.714, 0.759, 0.6335, 0.7855, 0.7014, 0.5401, 0.7480, 0.9580
# Hokkaido Iburi-Tobu, 19, 0.659, 0.771, 0.6370, 0.7696, 0.6970, 0.5350, 0.7454, 0.9580
# Hokkaido Iburi-Tobu, 20, 0.648, 0.808, 0.6370, 0.7569, 0.6918, 0.5288, 0.7422, 0.9576
# Hokkaido Iburi-Tobu, 21, 0.636, 0.776, 0.6570, 0.7628, 0.7060, 0.5455, 0.7518, 0.9601
# Hokkaido Iburi-Tobu, 22, 0.641, 0.759, 0.6467, 0.7718, 0.7037, 0.5429, 0.7500, 0.9592
# Hokkaido Iburi-Tobu, 23, 0.677, 0.734, 0.6653, 0.7720, 0.7147, 0.5561, 0.7577, 0.9613
# Hokkaido Iburi-Tobu, 24, 0.621, 0.763, 0.6373, 0.7779, 0.7006, 0.5392, 0.7476, 0.9582
# Hokkaido Iburi-Tobu, 25, 0.614, 0.715, 0.6803, 0.7730, 0.7237, 0.5670, 0.7640, 0.9629
# Hokkaido Iburi-Tobu, 26, 0.606, 0.723, 0.6940, 0.7540, 0.7227, 0.5659, 0.7639, 0.9637
# Hokkaido Iburi-Tobu, 27, 0.602, 0.730, 0.6449, 0.7816, 0.7067, 0.5465, 0.7518, 0.9593
# Hokkaido Iburi-Tobu, 28, 0.632, 0.692, 0.6550, 0.7990, 0.7199, 0.5624, 0.7606, 0.9609
# Hokkaido Iburi-Tobu, 29, 0.595, 0.687, 0.6360, 0.8182, 0.7157, 0.5572, 0.7571, 0.9592
# Hokkaido Iburi-Tobu, 30, 0.643, 0.678, 0.6702, 0.7953, 0.7274, 0.5716, 0.7661, 0.9626
# Hokkaido Iburi-Tobu, 31, 0.604, 0.698, 0.6574, 0.7943, 0.7194, 0.5618, 0.7604, 0.9611
# Hokkaido Iburi-Tobu, 32, 0.589, 0.700, 0.6403, 0.8121, 0.7160, 0.5577, 0.7575, 0.9595
# Hokkaido Iburi-Tobu, 33, 0.585, 0.677, 0.6570, 0.7906, 0.7176, 0.5596, 0.7592, 0.9609
# Hokkaido Iburi-Tobu, 34, 0.552, 0.636, 0.6660, 0.8071, 0.7298, 0.5745, 0.7675, 0.9625
# Hokkaido Iburi-Tobu, 35, 0.561, 0.666, 0.6711, 0.7936, 0.7272, 0.5714, 0.7660, 0.9626
# Hokkaido Iburi-Tobu, 36, 0.629, 0.878, 0.7015, 0.7382, 0.7193, 0.5617, 0.7619, 0.9638
# Hokkaido Iburi-Tobu, 37, 0.578, 0.917, 0.7242, 0.7169, 0.7206, 0.5632, 0.7633, 0.9651
# Hokkaido Iburi-Tobu, 38, 0.600, 0.860, 0.7545, 0.6967, 0.7244, 0.5679, 0.7666, 0.9667
# Hokkaido Iburi-Tobu, 39, 0.573, 0.668, 0.6529, 0.8115, 0.7236, 0.5669, 0.7629, 0.9611
# Hokkaido Iburi-Tobu, 40, 0.584, 0.677, 0.6385, 0.8193, 0.7177, 0.5597, 0.7585, 0.9595
# Hokkaido Iburi-Tobu, Jiuzhai valley (UAV-0.2m), 0.7811, 0.5185, 0.6233, 0.4527, 0.6388, 0.8470
# Hokkaido Iburi-Tobu, Jiuzhai valley (UAV-0.5m), 0.6686, 0.6360, 0.6519, 0.4835, 0.6998, 0.9221
# Hokkaido Iburi-Tobu, Lombok, 0.1710, 0.5053, 0.2555, 0.1464, 0.5277, 0.9103
# Hokkaido Iburi-Tobu, Longxi River (SAT), 0.0000, 0.0000, 0.0000, 0.0000, 0.4504, 0.9009
# Hokkaido Iburi-Tobu, Longxi River (UAV), 0.6772, 0.0811, 0.1449, 0.0781, 0.4585, 0.8411
# Hokkaido Iburi-Tobu, Mengdong Township, 0.3871, 0.3017, 0.3391, 0.2042, 0.5422, 0.8837
# Hokkaido Iburi-Tobu, Moxi town (UAV-0.2m), 0.3535, 0.3964, 0.3737, 0.2298, 0.5031, 0.7904
# Hokkaido Iburi-Tobu, Moxi town (UAV-1m), 0.2445, 0.6756, 0.3591, 0.2189, 0.5235, 0.8361
# Hokkaido Iburi-Tobu, Moxitaidi (SAT), 0.2927, 0.3812, 0.3311, 0.1984, 0.5484, 0.9008
# Hokkaido Iburi-Tobu, Moxitaidi (UAV-0.6m), 0.2809, 0.3135, 0.2963, 0.1739, 0.5188, 0.8674
# Hokkaido Iburi-Tobu, Moxitaidi (UAV-1m), 0.1757, 0.4388, 0.2509, 0.1434, 0.4688, 0.8010
# Hokkaido Iburi-Tobu, palu, 0.1250, 0.3117, 0.1784, 0.0979, 0.5328, 0.9677
# Hokkaido Iburi-Tobu, Tiburon Peninsula (planet), 0.4628, 0.6811, 0.5511, 0.3804, 0.6502, 0.9239
# Hokkaido Iburi-Tobu, Tiburon Peninsula (Sentinel), 0.1920, 0.6777, 0.2992, 0.1759, 0.5301, 0.8872
# Hokkaido Iburi-Tobu, Wenchuan, 0.3826, 0.6633, 0.4852, 0.3203, 0.6272, 0.9361
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Jiuzhai valley (UAV-0.2m), 1, 1.977, 1.866, 0.0000, 0.0000, 0.0000, 0.0000, 0.4005, 0.8011
# Jiuzhai valley (UAV-0.2m), 2, 1.888, 1.846, 0.0000, 0.0000, 0.0000, 0.0000, 0.4005, 0.8011
# Jiuzhai valley (UAV-0.2m), 3, 1.790, 1.808, 0.0000, 0.0000, 0.0000, 0.0000, 0.4005, 0.8011
# Jiuzhai valley (UAV-0.2m), 4, 1.703, 1.713, 0.7161, 0.4390, 0.5443, 0.3739, 0.6069, 0.8538
# Jiuzhai valley (UAV-0.2m), 5, 1.522, 1.602, 0.4708, 0.8479, 0.6055, 0.4342, 0.5849, 0.7802
# Jiuzhai valley (UAV-0.2m), 6, 1.500, 1.572, 0.4395, 0.8785, 0.5859, 0.4143, 0.5575, 0.7529
# Jiuzhai valley (UAV-0.2m), 7, 1.397, 1.537, 0.5733, 0.7687, 0.6568, 0.4889, 0.6501, 0.8402
# Jiuzhai valley (UAV-0.2m), 8, 1.367, 1.537, 0.5827, 0.7723, 0.6642, 0.4973, 0.6569, 0.8447
# Jiuzhai valley (UAV-0.2m), 9, 1.306, 1.456, 0.5764, 0.8087, 0.6731, 0.5072, 0.6605, 0.8437
# Jiuzhai valley (UAV-0.2m), 10, 1.225, 1.377, 0.5527, 0.8569, 0.6719, 0.5059, 0.6526, 0.8335
# Jiuzhai valley (UAV-0.2m), 11, 1.206, 1.336, 0.5623, 0.8528, 0.6778, 0.5126, 0.6592, 0.8387
# Jiuzhai valley (UAV-0.2m), 12, 1.183, 1.247, 0.6376, 0.8074, 0.7125, 0.5534, 0.6995, 0.8704
# Jiuzhai valley (UAV-0.2m), 13, 1.107, 1.131, 0.5777, 0.8780, 0.6969, 0.5348, 0.6753, 0.8480
# Jiuzhai valley (UAV-0.2m), 14, 1.053, 1.104, 0.5655, 0.8848, 0.6900, 0.5268, 0.6674, 0.8419
# Jiuzhai valley (UAV-0.2m), 15, 0.941, 0.955, 0.6125, 0.8674, 0.7180, 0.5600, 0.6981, 0.8644
# Jiuzhai valley (UAV-0.2m), 16, 1.006, 1.225, 0.6257, 0.8307, 0.7138, 0.5549, 0.6981, 0.8674
# Jiuzhai valley (UAV-0.2m), 17, 1.052, 1.252, 0.5847, 0.8411, 0.6899, 0.5266, 0.6729, 0.8495
# Jiuzhai valley (UAV-0.2m), 18, 0.958, 1.032, 0.4912, 0.9258, 0.6419, 0.4726, 0.6103, 0.7945
# Jiuzhai valley (UAV-0.2m), 19, 0.884, 0.997, 0.5184, 0.9339, 0.6667, 0.5001, 0.6360, 0.8143
# Jiuzhai valley (UAV-0.2m), 20, 0.844, 0.976, 0.5770, 0.9300, 0.7121, 0.5530, 0.6847, 0.8504
# Jiuzhai valley (UAV-0.2m), 21, 0.840, 0.999, 0.6681, 0.8584, 0.7514, 0.6018, 0.7328, 0.8870
# Jiuzhai valley (UAV-0.2m), 22, 0.812, 0.947, 0.5168, 0.9560, 0.6709, 0.5048, 0.6372, 0.8134
# Jiuzhai valley (UAV-0.2m), 23, 0.778, 0.910, 0.5478, 0.9423, 0.6928, 0.5300, 0.6627, 0.8338
# Jiuzhai valley (UAV-0.2m), 24, 0.791, 0.868, 0.5865, 0.9243, 0.7176, 0.5596, 0.6912, 0.8553
# Jiuzhai valley (UAV-0.2m), 25, 0.632, 1.004, 0.5519, 0.9286, 0.6924, 0.5295, 0.6640, 0.8358
# Jiuzhai valley (UAV-0.2m), 26, 0.723, 1.045, 0.5014, 0.9154, 0.6479, 0.4792, 0.6186, 0.8021
# Jiuzhai valley (UAV-0.2m), 27, 0.729, 1.094, 0.4241, 0.9736, 0.5909, 0.4193, 0.5433, 0.7318
# Jiuzhai valley (UAV-0.2m), 28, 0.662, 0.988, 0.5865, 0.8998, 0.7101, 0.5506, 0.6863, 0.8539
# Jiuzhai valley (UAV-0.2m), 29, 0.730, 0.916, 0.5143, 0.9687, 0.6719, 0.5059, 0.6364, 0.8118
# Jiuzhai valley (UAV-0.2m), 30, 0.688, 0.941, 0.5668, 0.9285, 0.7039, 0.5431, 0.6763, 0.8446
# Jiuzhai valley (UAV-0.2m), 31, 0.701, 1.205, 0.5659, 0.9092, 0.6976, 0.5356, 0.6721, 0.8432
# Jiuzhai valley (UAV-0.2m), Hokkaido Iburi-Tobu, 0.4644, 0.6517, 0.5423, 0.3720, 0.6316, 0.8978
# Jiuzhai valley (UAV-0.2m), Jiuzhai valley (UAV-0.5m), 0.6066, 0.8488, 0.7075, 0.5474, 0.7292, 0.9195
# Jiuzhai valley (UAV-0.2m), Lombok, 0.1064, 0.5432, 0.1779, 0.0977, 0.4711, 0.8471
# Jiuzhai valley (UAV-0.2m), Longxi River (SAT), 0.0326, 0.0004, 0.0009, 0.0004, 0.4501, 0.8997
# Jiuzhai valley (UAV-0.2m), Longxi River (UAV), 0.4215, 0.5540, 0.4788, 0.3147, 0.5471, 0.7998
# Jiuzhai valley (UAV-0.2m), Mengdong Township, 0.3446, 0.7775, 0.4775, 0.3136, 0.5657, 0.8317
# Jiuzhai valley (UAV-0.2m), Moxi town (UAV-0.2m), 0.2784, 0.7719, 0.4092, 0.2572, 0.4284, 0.6484
# Jiuzhai valley (UAV-0.2m), Moxi town (UAV-1m), 0.1312, 0.9214, 0.2297, 0.1298, 0.3409, 0.5801
# Jiuzhai valley (UAV-0.2m), Moxitaidi (SAT), 0.2539, 0.7691, 0.3818, 0.2359, 0.5336, 0.8396
# Jiuzhai valley (UAV-0.2m), Moxitaidi (UAV-0.6m), 0.2189, 0.6928, 0.3327, 0.1996, 0.4679, 0.7526
# Jiuzhai valley (UAV-0.2m), Moxitaidi (UAV-1m), 0.1720, 0.7469, 0.2796, 0.1625, 0.4264, 0.7078
# Jiuzhai valley (UAV-0.2m), palu, 0.0227, 0.0828, 0.0357, 0.0182, 0.4839, 0.9496
# Jiuzhai valley (UAV-0.2m), Tiburon Peninsula (planet), 0.3340, 0.2600, 0.2924, 0.1712, 0.5417, 0.9137
# Jiuzhai valley (UAV-0.2m), Tiburon Peninsula (Sentinel), 0.2658, 0.3763, 0.3115, 0.1845, 0.5623, 0.9409
# Jiuzhai valley (UAV-0.2m), Wenchuan, 0.4341, 0.3078, 0.3602, 0.2196, 0.5846, 0.9503
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Jiuzhai valley (UAV-0.5m), 1, 1.763, 1.813, 0.0000, 0.0000, 0.0000, 0.0000, 0.4383, 0.8766
# Jiuzhai valley (UAV-0.5m), 2, 1.728, 1.799, 0.0000, 0.0000, 0.0000, 0.0000, 0.4383, 0.8766
# Jiuzhai valley (UAV-0.5m), 3, 1.686, 1.774, 0.0000, 0.0000, 0.0000, 0.0000, 0.4383, 0.8766
# Jiuzhai valley (UAV-0.5m), 4, 1.629, 1.723, 0.0000, 0.0000, 0.0000, 0.0000, 0.4383, 0.8766
# Jiuzhai valley (UAV-0.5m), 5, 1.536, 1.633, 0.5114, 0.3804, 0.4362, 0.2790, 0.5758, 0.8787
# Jiuzhai valley (UAV-0.5m), 6, 1.415, 1.515, 0.4991, 0.6562, 0.5670, 0.3957, 0.6305, 0.8763
# Jiuzhai valley (UAV-0.5m), 7, 1.252, 1.440, 0.4971, 0.7455, 0.5964, 0.4249, 0.6439, 0.8755
# Jiuzhai valley (UAV-0.5m), 8, 1.079, 1.292, 0.5823, 0.8019, 0.6747, 0.5091, 0.7016, 0.9046
# Jiuzhai valley (UAV-0.5m), 9, 0.884, 1.014, 0.7039, 0.7285, 0.7160, 0.5576, 0.7396, 0.9287
# Jiuzhai valley (UAV-0.5m), 10, 0.843, 0.897, 0.5925, 0.8948, 0.7129, 0.5539, 0.7270, 0.9111
# Jiuzhai valley (UAV-0.5m), 11, 0.893, 0.791, 0.5575, 0.8752, 0.6811, 0.5164, 0.7015, 0.8989
# Jiuzhai valley (UAV-0.5m), 12, 0.842, 0.707, 0.6515, 0.8533, 0.7388, 0.5858, 0.7513, 0.9256
# Jiuzhai valley (UAV-0.5m), 13, 0.860, 0.703, 0.7219, 0.8304, 0.7724, 0.6291, 0.7809, 0.9396
# Jiuzhai valley (UAV-0.5m), 14, 0.795, 0.671, 0.7146, 0.8458, 0.7746, 0.6322, 0.7822, 0.9393
# Jiuzhai valley (UAV-0.5m), 15, 0.800, 0.660, 0.6825, 0.8678, 0.7641, 0.6182, 0.7721, 0.9339
# Jiuzhai valley (UAV-0.5m), 16, 0.754, 0.643, 0.6660, 0.8892, 0.7616, 0.6150, 0.7689, 0.9313
# Jiuzhai valley (UAV-0.5m), 17, 0.752, 0.640, 0.6538, 0.8956, 0.7558, 0.6075, 0.7636, 0.9286
# Jiuzhai valley (UAV-0.5m), 18, 0.765, 0.650, 0.6810, 0.8770, 0.7667, 0.6216, 0.7739, 0.9341
# Jiuzhai valley (UAV-0.5m), 19, 0.767, 0.638, 0.7023, 0.8617, 0.7739, 0.6312, 0.7808, 0.9379
# Jiuzhai valley (UAV-0.5m), 20, 0.820, 0.638, 0.7511, 0.7968, 0.7733, 0.6304, 0.7832, 0.9423
# Jiuzhai valley (UAV-0.5m), 21, 0.770, 0.627, 0.7046, 0.8644, 0.7763, 0.6344, 0.7828, 0.9385
# Jiuzhai valley (UAV-0.5m), 22, 0.775, 0.630, 0.6723, 0.8862, 0.7646, 0.6189, 0.7716, 0.9327
# Jiuzhai valley (UAV-0.5m), 23, 0.746, 0.671, 0.6339, 0.9057, 0.7458, 0.5947, 0.7545, 0.9238
# Jiuzhai valley (UAV-0.5m), 24, 0.765, 0.660, 0.6629, 0.8880, 0.7591, 0.6118, 0.7669, 0.9305
# Jiuzhai valley (UAV-0.5m), 25, 0.769, 0.610, 0.7308, 0.8506, 0.7862, 0.6477, 0.7919, 0.9429
# Jiuzhai valley (UAV-0.5m), 26, 0.736, 0.606, 0.7181, 0.8615, 0.7833, 0.6438, 0.7890, 0.9412
# Jiuzhai valley (UAV-0.5m), 27, 0.711, 0.605, 0.6952, 0.8810, 0.7772, 0.6355, 0.7828, 0.9377
# Jiuzhai valley (UAV-0.5m), 28, 0.732, 0.602, 0.6871, 0.8905, 0.7757, 0.6336, 0.7811, 0.9364
# Jiuzhai valley (UAV-0.5m), 29, 0.771, 0.601, 0.6897, 0.8908, 0.7774, 0.6359, 0.7826, 0.9371
# Jiuzhai valley (UAV-0.5m), 30, 0.699, 0.606, 0.6892, 0.8848, 0.7749, 0.6325, 0.7806, 0.9366
# Jiuzhai valley (UAV-0.5m), 31, 0.726, 0.622, 0.7118, 0.8065, 0.7562, 0.6080, 0.7683, 0.9358
# Jiuzhai valley (UAV-0.5m), 32, 0.683, 0.618, 0.7126, 0.8708, 0.7838, 0.6445, 0.7890, 0.9407
# Jiuzhai valley (UAV-0.5m), 33, 0.762, 0.664, 0.6576, 0.9023, 0.7608, 0.6139, 0.7676, 0.9300
# Jiuzhai valley (UAV-0.5m), 34, 0.665, 0.760, 0.5583, 0.9227, 0.6957, 0.5334, 0.7105, 0.9004
# Jiuzhai valley (UAV-0.5m), 35, 0.649, 0.664, 0.6453, 0.8740, 0.7424, 0.5903, 0.7532, 0.9252
# Jiuzhai valley (UAV-0.5m), Hokkaido Iburi-Tobu, 0.6183, 0.6870, 0.6508, 0.4824, 0.7046, 0.9315
# Jiuzhai valley (UAV-0.5m), Jiuzhai valley (UAV-0.2m), 0.7366, 0.7459, 0.7412, 0.5888, 0.7167, 0.8729
# Jiuzhai valley (UAV-0.5m), Lombok, 0.1017, 0.6207, 0.1748, 0.0958, 0.4569, 0.8215
# Jiuzhai valley (UAV-0.5m), Longxi River (SAT), 0.1151, 0.0010, 0.0019, 0.0010, 0.4506, 0.9003
# Jiuzhai valley (UAV-0.5m), Longxi River (UAV), 0.6657, 0.2812, 0.3954, 0.2464, 0.5484, 0.8573
# Jiuzhai valley (UAV-0.5m), Mengdong Township, 0.4052, 0.7243, 0.5196, 0.3510, 0.6042, 0.8676
# Jiuzhai valley (UAV-0.5m), Moxi town (UAV-0.2m), 0.3069, 0.8240, 0.4472, 0.2880, 0.4593, 0.6786
# Jiuzhai valley (UAV-0.5m), Moxi town (UAV-1m), 0.1466, 0.9119, 0.2526, 0.1446, 0.3768, 0.6333
# Jiuzhai valley (UAV-0.5m), Moxitaidi (SAT), 0.3126, 0.6844, 0.4292, 0.2732, 0.5753, 0.8828
# Jiuzhai valley (UAV-0.5m), Moxitaidi (UAV-0.6m), 0.2394, 0.6351, 0.3477, 0.2104, 0.4928, 0.7878
# Jiuzhai valley (UAV-0.5m), Moxitaidi (UAV-1m), 0.1818, 0.7051, 0.2890, 0.1689, 0.4453, 0.7367
# Jiuzhai valley (UAV-0.5m), palu, 0.0456, 0.1415, 0.0690, 0.0357, 0.4963, 0.9570
# Jiuzhai valley (UAV-0.5m), Tiburon Peninsula (planet), 0.5812, 0.4315, 0.4953, 0.3292, 0.6335, 0.9397
# Jiuzhai valley (UAV-0.5m), Tiburon Peninsula (Sentinel), 0.2719, 0.4776, 0.3465, 0.2096, 0.5722, 0.9360
# Jiuzhai valley (UAV-0.5m), Wenchuan, 0.4868, 0.3990, 0.4385, 0.2809, 0.6168, 0.9536
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Lombok, 1, 1.681, 1.659, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 2, 1.659, 1.651, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 3, 1.636, 1.634, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 4, 1.599, 1.592, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 5, 1.530, 1.416, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 6, 1.354, 1.497, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 7, 1.306, 1.370, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 8, 1.266, 1.199, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 9, 1.225, 1.184, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 10, 1.214, 1.235, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 11, 1.155, 1.200, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 12, 1.155, 1.137, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 13, 1.162, 1.112, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 14, 1.119, 1.101, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 15, 1.121, 1.105, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 16, 1.098, 1.102, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 17, 1.099, 1.073, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 18, 1.038, 1.055, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 19, 1.015, 1.069, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 20, 1.065, 1.058, 0.0000, 0.0000, 0.0000, 0.0000, 0.4906, 0.9811
# Lombok, 21, 1.044, 1.011, 0.0092, 0.0001, 0.0002, 0.0001, 0.4905, 0.9809
# Lombok, 22, 1.049, 1.006, 0.0961, 0.0215, 0.0351, 0.0179, 0.4978, 0.9777
# Lombok, 23, 1.022, 1.033, 0.1437, 0.0938, 0.1135, 0.0602, 0.5162, 0.9724
# Lombok, 24, 0.964, 0.964, 0.2955, 0.1710, 0.2166, 0.1215, 0.5490, 0.9767
# Lombok, 25, 0.970, 0.944, 0.3254, 0.3620, 0.3427, 0.2068, 0.5902, 0.9738
# Lombok, 26, 0.945, 0.924, 0.3757, 0.4002, 0.3876, 0.2404, 0.6082, 0.9761
# Lombok, 27, 0.885, 1.007, 0.1488, 0.4103, 0.2184, 0.1226, 0.5334, 0.9446
# Lombok, 28, 0.832, 1.013, 0.1637, 0.5588, 0.2532, 0.1450, 0.5411, 0.9378
# Lombok, 29, 0.898, 0.939, 0.2517, 0.5230, 0.3398, 0.2047, 0.5830, 0.9617
# Lombok, 30, 0.881, 0.950, 0.4828, 0.1487, 0.2274, 0.1283, 0.5546, 0.9809
# Lombok, 31, 0.968, 0.916, 0.2468, 0.6357, 0.3556, 0.2162, 0.5861, 0.9565
# Lombok, 32, 0.965, 0.924, 0.2078, 0.5495, 0.3016, 0.1776, 0.5645, 0.9520
# Lombok, 33, 0.838, 0.881, 0.4303, 0.3803, 0.4037, 0.2529, 0.6158, 0.9788
# Lombok, 34, 0.885, 0.941, 0.1961, 0.6234, 0.2983, 0.1753, 0.5597, 0.9447
# Lombok, 35, 0.892, 0.927, 0.2131, 0.5743, 0.3109, 0.1841, 0.5677, 0.9520
# Lombok, 36, 0.823, 0.847, 0.5679, 0.3623, 0.4424, 0.2840, 0.6333, 0.9828
# Lombok, 37, 0.859, 0.829, 0.3814, 0.5621, 0.4544, 0.2940, 0.6341, 0.9745
# Lombok, 38, 0.826, 0.855, 0.2686, 0.6730, 0.3840, 0.2376, 0.5982, 0.9593
# Lombok, 39, 0.717, 0.798, 0.4182, 0.4607, 0.4384, 0.2807, 0.6291, 0.9777
# Lombok, 40, 0.934, 0.826, 0.3771, 0.4794, 0.4221, 0.2675, 0.6213, 0.9752
# Lombok, Hokkaido Iburi-Tobu, 0.2948, 0.1579, 0.2057, 0.1146, 0.4998, 0.8866
# Lombok, Jiuzhai valley (UAV-0.2m), 0.7752, 0.3208, 0.4538, 0.2935, 0.5445, 0.8116
# Lombok, Jiuzhai valley (UAV-0.5m), 0.5588, 0.4958, 0.5254, 0.3563, 0.6237, 0.8973
# Lombok, Longxi River (SAT), 0.4656, 0.0082, 0.0161, 0.0081, 0.4544, 0.9008
# Lombok, Longxi River (UAV), 0.0993, 0.1666, 0.1244, 0.0663, 0.3331, 0.6109
# Lombok, Mengdong Township, 0.0277, 0.0272, 0.0274, 0.0139, 0.4114, 0.8094
# Lombok, Moxi town (UAV-0.2m), 0.2076, 0.4307, 0.2802, 0.1629, 0.3942, 0.6509
# Lombok, Moxi town (UAV-1m), 0.0988, 0.9189, 0.1785, 0.0980, 0.2424, 0.4251
# Lombok, Moxitaidi (SAT), 0.0932, 0.0906, 0.0919, 0.0481, 0.4661, 0.8847
# Lombok, Moxitaidi (UAV-0.6m), 0.1562, 0.0826, 0.1080, 0.0571, 0.4674, 0.8786
# Lombok, Moxitaidi (UAV-1m), 0.0799, 0.1270, 0.0981, 0.0516, 0.4362, 0.8226
# Lombok, palu, 0.1911, 0.2549, 0.2185, 0.1226, 0.5510, 0.9795
# Lombok, Tiburon Peninsula (planet), 0.5464, 0.0662, 0.1180, 0.0627, 0.4973, 0.9322
# Lombok, Tiburon Peninsula (Sentinel), 0.3537, 0.3293, 0.3411, 0.2056, 0.5799, 0.9548
# Lombok, Wenchuan, 0.3198, 0.4155, 0.3614, 0.2206, 0.5763, 0.9333
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Longxi River (SAT), 1, 1.782, 1.774, 0.0000, 0.0000, 0.0000, 0.0000, 0.4602, 0.9203
# Longxi River (SAT), 2, 1.755, 1.770, 0.0000, 0.0000, 0.0000, 0.0000, 0.4602, 0.9203
# Longxi River (SAT), 3, 1.719, 1.760, 0.0000, 0.0000, 0.0000, 0.0000, 0.4602, 0.9203
# Longxi River (SAT), 4, 1.660, 1.741, 0.0000, 0.0000, 0.0000, 0.0000, 0.4602, 0.9203
# Longxi River (SAT), 5, 1.578, 1.696, 0.0000, 0.0000, 0.0000, 0.0000, 0.4602, 0.9203
# Longxi River (SAT), 6, 1.398, 1.774, 0.0000, 0.0000, 0.0000, 0.0000, 0.4602, 0.9203
# Longxi River (SAT), 7, 0.976, 4.389, 0.0000, 0.0000, 0.0000, 0.0000, 0.4602, 0.9203
# Longxi River (SAT), 8, 0.807, 3.039, 0.9719, 0.1320, 0.2325, 0.1315, 0.5307, 0.9305
# Longxi River (SAT), 9, 0.811, 1.337, 0.7849, 0.4847, 0.5993, 0.4278, 0.6871, 0.9484
# Longxi River (SAT), 10, 0.664, 0.934, 0.6193, 0.6787, 0.6477, 0.4789, 0.7084, 0.9412
# Longxi River (SAT), 11, 0.663, 1.022, 0.7318, 0.5987, 0.6586, 0.4910, 0.7195, 0.9505
# Longxi River (SAT), 12, 0.692, 0.830, 0.6855, 0.6843, 0.6849, 0.5208, 0.7339, 0.9498
# Longxi River (SAT), 13, 0.671, 0.862, 0.4892, 0.8938, 0.6323, 0.4623, 0.6866, 0.9172
# Longxi River (SAT), 14, 0.620, 0.742, 0.5789, 0.8146, 0.6768, 0.5115, 0.7226, 0.9380
# Longxi River (SAT), 15, 0.613, 0.774, 0.6281, 0.7452, 0.6817, 0.5171, 0.7291, 0.9446
# Longxi River (SAT), 16, 0.613, 0.717, 0.6099, 0.7982, 0.6914, 0.5284, 0.7339, 0.9432
# Longxi River (SAT), 17, 0.673, 0.766, 0.6374, 0.7606, 0.6936, 0.5309, 0.7370, 0.9465
# Longxi River (SAT), 18, 0.658, 0.960, 0.3703, 0.9227, 0.5285, 0.3591, 0.6088, 0.8688
# Longxi River (SAT), 19, 0.624, 0.708, 0.6043, 0.8094, 0.6920, 0.5290, 0.7338, 0.9426
# Longxi River (SAT), 20, 0.676, 0.791, 0.6641, 0.7166, 0.6893, 0.5259, 0.7357, 0.9485
# Longxi River (SAT), 21, 0.642, 0.716, 0.5991, 0.8010, 0.6855, 0.5215, 0.7295, 0.9414
# Longxi River (SAT), 22, 0.603, 0.699, 0.5853, 0.8293, 0.6862, 0.5223, 0.7288, 0.9396
# Longxi River (SAT), 23, 0.682, 0.751, 0.6034, 0.7973, 0.6869, 0.5231, 0.7306, 0.9421
# Longxi River (SAT), 24, 0.607, 0.729, 0.5140, 0.8990, 0.6540, 0.4859, 0.7022, 0.9242
# Longxi River (SAT), 25, 0.595, 0.682, 0.5813, 0.8485, 0.6899, 0.5266, 0.7307, 0.9392
# Longxi River (SAT), 26, 0.580, 0.694, 0.6147, 0.8130, 0.7001, 0.5385, 0.7396, 0.9445
# Longxi River (SAT), 27, 0.548, 0.705, 0.6080, 0.8153, 0.6965, 0.5344, 0.7369, 0.9434
# Longxi River (SAT), 28, 0.568, 0.676, 0.5942, 0.8408, 0.6963, 0.5341, 0.7357, 0.9416
# Longxi River (SAT), 29, 0.705, 1.260, 0.6796, 0.6670, 0.6732, 0.5074, 0.7265, 0.9484
# Longxi River (SAT), 30, 0.630, 0.945, 0.5836, 0.7690, 0.6636, 0.4965, 0.7152, 0.9379
# Longxi River (SAT), 31, 0.591, 0.780, 0.6015, 0.7925, 0.6839, 0.5196, 0.7287, 0.9416
# Longxi River (SAT), 32, 0.635, 0.842, 0.4371, 0.9149, 0.5915, 0.4200, 0.6557, 0.8993
# Longxi River (SAT), 33, 0.628, 0.712, 0.5609, 0.8472, 0.6750, 0.5094, 0.7199, 0.9350
# Longxi River (SAT), 34, 0.587, 0.743, 0.6422, 0.7634, 0.6976, 0.5356, 0.7397, 0.9473
# Longxi River (SAT), 35, 0.636, 0.720, 0.5532, 0.8610, 0.6736, 0.5079, 0.7183, 0.9335
# Longxi River (SAT), 36, 0.583, 0.699, 0.5802, 0.8418, 0.6869, 0.5231, 0.7288, 0.9389
# Longxi River (SAT), Hokkaido Iburi-Tobu, 0.7885, 0.2348, 0.3619, 0.2209, 0.5711, 0.9230
# Longxi River (SAT), Jiuzhai valley (UAV-0.2m), 0.5050, 0.6827, 0.5806, 0.4090, 0.5601, 0.7593
# Longxi River (SAT), Jiuzhai valley (UAV-0.5m), 0.3330, 0.6900, 0.4492, 0.2896, 0.5395, 0.8060
# Longxi River (SAT), Lombok, 0.0805, 0.4022, 0.1342, 0.0719, 0.4559, 0.8418
# Longxi River (SAT), Longxi River (UAV), 0.1072, 0.0443, 0.0627, 0.0324, 0.4055, 0.7802
# Longxi River (SAT), Mengdong Township, 0.4871, 0.2779, 0.3539, 0.2150, 0.5559, 0.8996
# Longxi River (SAT), Moxi town (UAV-0.2m), 0.2670, 0.6742, 0.3825, 0.2365, 0.4261, 0.6566
# Longxi River (SAT), Moxi town (UAV-1m), 0.1246, 0.3373, 0.1819, 0.1001, 0.4445, 0.7938
# Longxi River (SAT), Moxitaidi (SAT), 0.6631, 0.0824, 0.1466, 0.0791, 0.5085, 0.9382
# Longxi River (SAT), Moxitaidi (UAV-0.6m), 0.2828, 0.5497, 0.3735, 0.2296, 0.5285, 0.8358
# Longxi River (SAT), Moxitaidi (UAV-1m), 0.2131, 0.3706, 0.2706, 0.1565, 0.5002, 0.8483
# Longxi River (SAT), palu, 0.0148, 0.0697, 0.0244, 0.0123, 0.4747, 0.9371
# Longxi River (SAT), Tiburon Peninsula (planet), 0.2043, 0.4404, 0.2791, 0.1622, 0.5006, 0.8439
# Longxi River (SAT), Tiburon Peninsula (Sentinel), 0.0778, 0.0351, 0.0483, 0.0248, 0.4878, 0.9509
# Longxi River (SAT), Wenchuan, 0.2461, 0.3178, 0.2774, 0.1610, 0.5423, 0.9248
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Longxi River (UAV), 1, 1.824, 1.868, 0.0000, 0.0000, 0.0000, 0.0000, 0.4235, 0.8471
# Longxi River (UAV), 2, 1.776, 1.856, 0.0000, 0.0000, 0.0000, 0.0000, 0.4235, 0.8471
# Longxi River (UAV), 3, 1.720, 1.830, 0.0000, 0.0000, 0.0000, 0.0000, 0.4235, 0.8471
# Longxi River (UAV), 4, 1.649, 1.780, 0.4785, 0.1014, 0.1673, 0.0913, 0.4673, 0.8457
# Longxi River (UAV), 5, 1.561, 1.686, 0.5559, 0.5272, 0.5411, 0.3709, 0.6111, 0.8633
# Longxi River (UAV), 6, 1.474, 1.574, 0.5476, 0.6500, 0.5944, 0.4229, 0.6362, 0.8643
# Longxi River (UAV), 7, 1.337, 1.413, 0.5606, 0.5618, 0.5612, 0.3901, 0.6215, 0.8656
# Longxi River (UAV), 8, 1.212, 1.270, 0.5393, 0.7131, 0.6141, 0.4431, 0.6447, 0.8630
# Longxi River (UAV), 9, 1.163, 1.411, 0.5473, 0.6383, 0.5893, 0.4178, 0.6335, 0.8639
# Longxi River (UAV), 10, 1.125, 1.317, 0.5394, 0.6760, 0.6000, 0.4286, 0.6374, 0.8622
# Longxi River (UAV), 11, 1.092, 1.199, 0.5331, 0.7328, 0.6172, 0.4464, 0.6449, 0.8610
# Longxi River (UAV), 12, 1.085, 1.196, 0.5285, 0.7542, 0.6215, 0.4509, 0.6460, 0.8595
# Longxi River (UAV), 13, 1.059, 1.151, 0.5186, 0.7920, 0.6268, 0.4564, 0.6462, 0.8558
# Longxi River (UAV), 14, 1.280, 1.160, 0.4942, 0.8281, 0.6190, 0.4482, 0.6348, 0.8441
# Longxi River (UAV), 15, 1.187, 1.151, 0.4998, 0.8158, 0.6198, 0.4491, 0.6371, 0.8470
# Longxi River (UAV), 16, 1.124, 1.130, 0.5036, 0.8054, 0.6197, 0.4490, 0.6383, 0.8488
# Longxi River (UAV), 17, 1.124, 1.123, 0.5030, 0.8031, 0.6186, 0.4478, 0.6376, 0.8485
# Longxi River (UAV), 18, 1.058, 1.091, 0.4952, 0.8246, 0.6188, 0.4480, 0.6351, 0.8446
# Longxi River (UAV), 19, 1.153, 1.088, 0.4958, 0.8247, 0.6193, 0.4485, 0.6355, 0.8449
# Longxi River (UAV), 20, 1.020, 1.095, 0.4994, 0.8196, 0.6206, 0.4499, 0.6374, 0.8467
# Longxi River (UAV), 21, 1.039, 1.084, 0.4990, 0.8300, 0.6233, 0.4527, 0.6385, 0.8465
# Longxi River (UAV), 22, 1.042, 1.093, 0.4997, 0.8328, 0.6246, 0.4542, 0.6394, 0.8469
# Longxi River (UAV), 23, 0.990, 1.064, 0.5041, 0.8342, 0.6284, 0.4582, 0.6426, 0.8491
# Longxi River (UAV), 24, 0.976, 1.059, 0.4918, 0.8544, 0.6243, 0.4538, 0.6364, 0.8427
# Longxi River (UAV), 25, 0.935, 1.085, 0.4957, 0.8435, 0.6244, 0.4539, 0.6379, 0.8448
# Longxi River (UAV), 26, 0.912, 1.078, 0.4993, 0.8455, 0.6279, 0.4576, 0.6407, 0.8467
# Longxi River (UAV), 27, 0.902, 1.072, 0.5030, 0.8491, 0.6318, 0.4617, 0.6439, 0.8486
# Longxi River (UAV), 28, 0.870, 1.151, 0.5294, 0.7926, 0.6348, 0.4650, 0.6531, 0.8605
# Longxi River (UAV), 29, 0.953, 1.261, 0.5550, 0.7417, 0.6349, 0.4651, 0.6589, 0.8695
# Longxi River (UAV), 30, 0.983, 1.060, 0.5163, 0.8439, 0.6407, 0.4713, 0.6525, 0.8552
# Longxi River (UAV), 31, 0.987, 1.100, 0.5326, 0.7974, 0.6386, 0.4691, 0.6559, 0.8620
# Longxi River (UAV), 32, 0.928, 1.103, 0.5342, 0.7890, 0.6370, 0.4674, 0.6555, 0.8625
# Longxi River (UAV), 33, 0.975, 1.038, 0.5368, 0.8391, 0.6548, 0.4867, 0.6657, 0.8647
# Longxi River (UAV), 34, 0.889, 1.008, 0.5298, 0.8706, 0.6587, 0.4911, 0.6660, 0.8620
# Longxi River (UAV), 35, 0.890, 1.073, 0.5207, 0.8205, 0.6371, 0.4675, 0.6520, 0.8570
# Longxi River (UAV), 36, 0.788, 1.155, 0.5339, 0.7796, 0.6338, 0.4639, 0.6537, 0.8622
# Longxi River (UAV), 37, 0.836, 1.112, 0.5372, 0.7897, 0.6394, 0.4700, 0.6575, 0.8638
# Longxi River (UAV), 38, 0.797, 1.050, 0.5295, 0.8277, 0.6458, 0.4769, 0.6590, 0.8611
# Longxi River (UAV), 39, 0.792, 1.023, 0.5380, 0.8477, 0.6583, 0.4906, 0.6680, 0.8654
# Longxi River (UAV), 40, 0.746, 1.081, 0.5263, 0.8327, 0.6450, 0.4760, 0.6577, 0.8598
# Longxi River (UAV), Hokkaido Iburi-Tobu, 0.2227, 0.8413, 0.3522, 0.2138, 0.4509, 0.7124
# Longxi River (UAV), Jiuzhai valley (UAV-0.2m), 0.6725, 0.5498, 0.6050, 0.4337, 0.6157, 0.8248
# Longxi River (UAV), Jiuzhai valley (UAV-0.5m), 0.5852, 0.6004, 0.5927, 0.4212, 0.6598, 0.9054
# Longxi River (UAV), Lombok, 0.0818, 0.5804, 0.1434, 0.0772, 0.4310, 0.7887
# Longxi River (UAV), Longxi River (SAT), 0.1335, 0.0125, 0.0229, 0.0116, 0.4528, 0.8941
# Longxi River (UAV), Mengdong Township, 0.2295, 0.9009, 0.3658, 0.2238, 0.4423, 0.6910
# Longxi River (UAV), Moxi town (UAV-0.2m), 0.2545, 0.5383, 0.3456, 0.2089, 0.4287, 0.6784
# Longxi River (UAV), Moxi town (UAV-1m), 0.1304, 0.7820, 0.2235, 0.1258, 0.3679, 0.6307
# Longxi River (UAV), Moxitaidi (SAT), 0.1860, 0.8420, 0.3048, 0.1798, 0.4591, 0.7526
# Longxi River (UAV), Moxitaidi (UAV-0.6m), 0.1876, 0.6410, 0.2903, 0.1698, 0.4369, 0.7209
# Longxi River (UAV), Moxitaidi (UAV-1m), 0.1449, 0.7292, 0.2418, 0.1375, 0.3850, 0.6528
# Longxi River (UAV), palu, 0.0346, 0.3888, 0.0635, 0.0328, 0.4516, 0.8709
# Longxi River (UAV), Tiburon Peninsula (planet), 0.1451, 0.9256, 0.2509, 0.1435, 0.3693, 0.6208
# Longxi River (UAV), Tiburon Peninsula (Sentinel), 0.0968, 0.8332, 0.1734, 0.0949, 0.4020, 0.7176
# Longxi River (UAV), Wenchuan, 0.4565, 0.5640, 0.5046, 0.3374, 0.6429, 0.9497
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Mengdong Township, 1, 1.720, 1.760, 0.0000, 0.0000, 0.0000, 0.0000, 0.4425, 0.8851
# Mengdong Township, 2, 1.669, 1.744, 0.0000, 0.0000, 0.0000, 0.0000, 0.4425, 0.8851
# Mengdong Township, 3, 1.620, 1.719, 0.0000, 0.0000, 0.0000, 0.0000, 0.4425, 0.8851
# Mengdong Township, 4, 1.573, 1.679, 0.7132, 0.0759, 0.1372, 0.0736, 0.4815, 0.8903
# Mengdong Township, 5, 1.517, 1.616, 0.4927, 0.3586, 0.4151, 0.2619, 0.5704, 0.8839
# Mengdong Township, 6, 1.380, 1.574, 0.6884, 0.0765, 0.1376, 0.0739, 0.4814, 0.8899
# Mengdong Township, 7, 1.135, 7.400, 0.8983, 0.0162, 0.0317, 0.0161, 0.4513, 0.8867
# Mengdong Township, 8, 0.990, 6.592, 0.8166, 0.0495, 0.0933, 0.0489, 0.4689, 0.8895
# Mengdong Township, 9, 0.920, 1.528, 0.7037, 0.3651, 0.4808, 0.3165, 0.6109, 0.9094
# Mengdong Township, 10, 0.928, 0.986, 0.5775, 0.6791, 0.6242, 0.4537, 0.6759, 0.9060
# Mengdong Township, 11, 0.993, 0.951, 0.5347, 0.7554, 0.6262, 0.4558, 0.6712, 0.8964
# Mengdong Township, 12, 1.012, 1.108, 0.4179, 0.7901, 0.5466, 0.3761, 0.6053, 0.8494
# Mengdong Township, 13, 0.964, 1.021, 0.4846, 0.7186, 0.5789, 0.4073, 0.6382, 0.8799
# Mengdong Township, 14, 0.915, 1.017, 0.5604, 0.6461, 0.6002, 0.4287, 0.6609, 0.9011
# Mengdong Township, 15, 0.895, 0.972, 0.5640, 0.6747, 0.6144, 0.4434, 0.6690, 0.9027
# Mengdong Township, 16, 0.846, 0.876, 0.6696, 0.6780, 0.6737, 0.5080, 0.7131, 0.9246
# Mengdong Township, 17, 0.836, 0.876, 0.5772, 0.7378, 0.6477, 0.4789, 0.6891, 0.9078
# Mengdong Township, 18, 0.768, 0.874, 0.6817, 0.6950, 0.6883, 0.5247, 0.7230, 0.9277
# Mengdong Township, 19, 0.759, 0.857, 0.5554, 0.7729, 0.6464, 0.4775, 0.6854, 0.9028
# Mengdong Township, 20, 0.766, 0.839, 0.5715, 0.7760, 0.6582, 0.4906, 0.6945, 0.9074
# Mengdong Township, 21, 0.868, 0.829, 0.5733, 0.7639, 0.6550, 0.4870, 0.6928, 0.9075
# Mengdong Township, 22, 0.807, 0.852, 0.5442, 0.7595, 0.6341, 0.4642, 0.6769, 0.8993
# Mengdong Township, 23, 0.790, 0.810, 0.5975, 0.7465, 0.6638, 0.4967, 0.7008, 0.9131
# Mengdong Township, 24, 0.720, 0.792, 0.6483, 0.7396, 0.6910, 0.5278, 0.7224, 0.9240
# Mengdong Township, 25, 0.698, 0.785, 0.6560, 0.7550, 0.7020, 0.5409, 0.7301, 0.9264
# Mengdong Township, 26, 0.718, 0.780, 0.5904, 0.7925, 0.6767, 0.5113, 0.7078, 0.9130
# Mengdong Township, 27, 0.711, 0.780, 0.6476, 0.7865, 0.7103, 0.5508, 0.7349, 0.9263
# Mengdong Township, 28, 0.676, 0.762, 0.6201, 0.8015, 0.6992, 0.5375, 0.7251, 0.9208
# Mengdong Township, 29, 0.678, 0.832, 0.5820, 0.8017, 0.6744, 0.5087, 0.7054, 0.9110
# Mengdong Township, 30, 0.653, 0.782, 0.6669, 0.7739, 0.7164, 0.5582, 0.7405, 0.9296
# Mengdong Township, 31, 0.636, 0.747, 0.5980, 0.8447, 0.7003, 0.5388, 0.7234, 0.9169
# Mengdong Township, 32, 0.586, 0.719, 0.6267, 0.8467, 0.7203, 0.5628, 0.7396, 0.9244
# Mengdong Township, 33, 0.580, 0.751, 0.6522, 0.8022, 0.7195, 0.5619, 0.7413, 0.9281
# Mengdong Township, 34, 0.510, 0.755, 0.7070, 0.7638, 0.7343, 0.5801, 0.7553, 0.9365
# Mengdong Township, 35, 0.490, 0.823, 0.6475, 0.7972, 0.7146, 0.5559, 0.7377, 0.9268
# Mengdong Township, 36, 0.496, 0.748, 0.6568, 0.8199, 0.7293, 0.5740, 0.7484, 0.9301
# Mengdong Township, 37, 0.437, 0.752, 0.6938, 0.7770, 0.7331, 0.5786, 0.7536, 0.9350
# Mengdong Township, 38, 0.414, 0.830, 0.6394, 0.8030, 0.7119, 0.5527, 0.7352, 0.9253
# Mengdong Township, 39, 0.372, 0.843, 0.6460, 0.8332, 0.7277, 0.5720, 0.7464, 0.9284
# Mengdong Township, 40, 0.398, 0.842, 0.6883, 0.7925, 0.7367, 0.5832, 0.7558, 0.9349
# Mengdong Township, Hokkaido Iburi-Tobu, 0.7916, 0.1612, 0.2678, 0.1546, 0.5357, 0.9181
# Mengdong Township, Jiuzhai valley (UAV-0.2m), 0.8062, 0.5864, 0.6789, 0.5139, 0.6780, 0.8647
# Mengdong Township, Jiuzhai valley (UAV-0.5m), 0.8172, 0.4687, 0.5957, 0.4242, 0.6736, 0.9271
# Mengdong Township, Lombok, 0.0608, 0.0998, 0.0756, 0.0393, 0.4823, 0.9256
# Mengdong Township, Longxi River (SAT), 0.2736, 0.0032, 0.0064, 0.0032, 0.4518, 0.9004
# Mengdong Township, Longxi River (UAV), 0.6231, 0.0820, 0.1450, 0.0782, 0.4577, 0.8394
# Mengdong Township, Moxi town (UAV-0.2m), 0.6130, 0.1340, 0.2200, 0.1236, 0.4852, 0.8501
# Mengdong Township, Moxi town (UAV-1m), 0.0752, 0.0301, 0.0430, 0.0220, 0.4654, 0.9089
# Mengdong Township, Moxitaidi (SAT), 0.7013, 0.2302, 0.3466, 0.2096, 0.5765, 0.9441
# Mengdong Township, Moxitaidi (UAV-0.6m), 0.5463, 0.3699, 0.4411, 0.2830, 0.5983, 0.9165
# Mengdong Township, Moxitaidi (UAV-1m), 0.5103, 0.2935, 0.3726, 0.2290, 0.5761, 0.9250
# Mengdong Township, palu, 0.0362, 0.0661, 0.0468, 0.0239, 0.4968, 0.9696
# Mengdong Township, Tiburon Peninsula (planet), 0.4067, 0.6269, 0.4933, 0.3274, 0.6175, 0.9116
# Mengdong Township, Tiburon Peninsula (Sentinel), 0.2060, 0.0947, 0.1298, 0.0694, 0.5120, 0.9548
# Mengdong Township, Wenchuan, 0.5735, 0.3823, 0.4587, 0.2976, 0.6280, 0.9590
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Moxi town (UAV-0.2m), 1, 1.773, 1.941, 0.0000, 0.0000, 0.0000, 0.0000, 0.3676, 0.7353
# Moxi town (UAV-0.2m), 2, 1.751, 1.936, 0.0000, 0.0000, 0.0000, 0.0000, 0.3676, 0.7353
# Moxi town (UAV-0.2m), 3, 1.726, 1.929, 0.0000, 0.0000, 0.0000, 0.0000, 0.3676, 0.7353
# Moxi town (UAV-0.2m), 4, 1.692, 1.921, 0.0000, 0.0000, 0.0000, 0.0000, 0.3676, 0.7353
# Moxi town (UAV-0.2m), 5, 1.646, 1.914, 0.0000, 0.0000, 0.0000, 0.0000, 0.3676, 0.7353
# Moxi town (UAV-0.2m), 6, 1.591, 2.060, 0.0000, 0.0000, 0.0000, 0.0000, 0.3676, 0.7353
# Moxi town (UAV-0.2m), 7, 1.521, 1.900, 0.0863, 0.0087, 0.0158, 0.0080, 0.3602, 0.7132
# Moxi town (UAV-0.2m), 8, 1.505, 1.852, 0.3428, 0.1262, 0.1845, 0.1016, 0.3980, 0.7046
# Moxi town (UAV-0.2m), 9, 1.471, 1.793, 0.3524, 0.2032, 0.2578, 0.1480, 0.4103, 0.6902
# Moxi town (UAV-0.2m), 10, 1.440, 1.749, 0.4850, 0.4274, 0.4544, 0.2940, 0.4938, 0.7283
# Moxi town (UAV-0.2m), 11, 1.341, 1.667, 0.7112, 0.5052, 0.5907, 0.4192, 0.6026, 0.8147
# Moxi town (UAV-0.2m), 12, 1.332, 1.768, 0.5821, 0.6036, 0.5926, 0.4211, 0.5798, 0.7803
# Moxi town (UAV-0.2m), 13, 1.310, 2.500, 0.6947, 0.5667, 0.6242, 0.4537, 0.6206, 0.8194
# Moxi town (UAV-0.2m), 14, 1.295, 1.723, 0.7215, 0.6252, 0.6699, 0.5036, 0.6541, 0.8369
# Moxi town (UAV-0.2m), 15, 1.211, 1.490, 0.6034, 0.7408, 0.6651, 0.4982, 0.6262, 0.8025
# Moxi town (UAV-0.2m), 16, 1.315, 1.319, 0.7055, 0.7389, 0.7218, 0.5647, 0.6886, 0.8492
# Moxi town (UAV-0.2m), 17, 1.416, 1.322, 0.6992, 0.7417, 0.7199, 0.5623, 0.6861, 0.8472
# Moxi town (UAV-0.2m), 18, 1.231, 1.379, 0.7571, 0.6957, 0.7251, 0.5687, 0.6988, 0.8603
# Moxi town (UAV-0.2m), 19, 1.093, 1.552, 0.5976, 0.6951, 0.6427, 0.4735, 0.6114, 0.7954
# Moxi town (UAV-0.2m), 20, 1.100, 1.533, 0.6536, 0.7074, 0.6794, 0.5145, 0.6485, 0.8233
# Moxi town (UAV-0.2m), 21, 1.057, 1.306, 0.7598, 0.7114, 0.7348, 0.5808, 0.7067, 0.8641
# Moxi town (UAV-0.2m), 22, 1.057, 1.424, 0.6456, 0.7410, 0.6900, 0.5267, 0.6537, 0.8237
# Moxi town (UAV-0.2m), 23, 0.990, 1.268, 0.8093, 0.7011, 0.7514, 0.6017, 0.7254, 0.8772
# Moxi town (UAV-0.2m), 24, 0.994, 1.315, 0.8121, 0.7069, 0.7559, 0.6075, 0.7294, 0.8791
# Moxi town (UAV-0.2m), 25, 0.985, 1.319, 0.7647, 0.7475, 0.7560, 0.6077, 0.7242, 0.8723
# Moxi town (UAV-0.2m), 26, 0.871, 1.333, 0.6595, 0.7856, 0.7171, 0.5590, 0.6759, 0.8359
# Moxi town (UAV-0.2m), 27, 0.899, 1.446, 0.7929, 0.6637, 0.7226, 0.5656, 0.7010, 0.8651
# Moxi town (UAV-0.2m), 28, 0.841, 1.388, 0.7867, 0.7250, 0.7546, 0.6059, 0.7257, 0.8752
# Moxi town (UAV-0.2m), 29, 0.777, 1.297, 0.6726, 0.8098, 0.7348, 0.5808, 0.6919, 0.8453
# Moxi town (UAV-0.2m), 30, 0.802, 1.161, 0.6889, 0.8516, 0.7617, 0.6151, 0.7164, 0.8589
# Moxi town (UAV-0.2m), 31, 0.740, 1.514, 0.7720, 0.7127, 0.7412, 0.5888, 0.7132, 0.8682
# Moxi town (UAV-0.2m), 32, 0.647, 1.652, 0.8094, 0.7075, 0.7550, 0.6065, 0.7285, 0.8785
# Moxi town (UAV-0.2m), 33, 0.556, 1.391, 0.7380, 0.8376, 0.7846, 0.6456, 0.7446, 0.8783
# Moxi town (UAV-0.2m), 34, 0.560, 1.983, 0.7930, 0.5481, 0.6482, 0.4795, 0.6476, 0.8425
# Moxi town (UAV-0.2m), 35, 0.891, 2.436, 0.7553, 0.6429, 0.6946, 0.5321, 0.6759, 0.8503
# Moxi town (UAV-0.2m), 36, 0.751, 1.829, 0.8299, 0.6493, 0.7286, 0.5731, 0.7092, 0.8719
# Moxi town (UAV-0.2m), 37, 0.726, 1.320, 0.7032, 0.8251, 0.7593, 0.6119, 0.7174, 0.8615
# Moxi town (UAV-0.2m), 38, 0.557, 1.295, 0.5947, 0.8785, 0.7093, 0.5495, 0.6506, 0.8094
# Moxi town (UAV-0.2m), 39, 0.507, 1.693, 0.7253, 0.7464, 0.7357, 0.5819, 0.7025, 0.8580
# Moxi town (UAV-0.2m), 40, 0.598, 2.222, 0.7072, 0.4843, 0.5749, 0.4034, 0.5930, 0.8104
# Moxi town (UAV-0.2m), Hokkaido Iburi-Tobu, 0.7045, 0.1126, 0.1941, 0.1075, 0.5098, 0.9131
# Moxi town (UAV-0.2m), Jiuzhai valley (UAV-0.2m), 0.6954, 0.7831, 0.7367, 0.5831, 0.7071, 0.8634
# Moxi town (UAV-0.2m), Jiuzhai valley (UAV-0.5m), 0.5933, 0.7844, 0.6756, 0.5101, 0.7076, 0.9136
# Moxi town (UAV-0.2m), Lombok, 0.0838, 0.3490, 0.1351, 0.0725, 0.4674, 0.8639
# Moxi town (UAV-0.2m), Longxi River (SAT), 0.0000, 0.0000, 0.0000, 0.0000, 0.4502, 0.9003
# Moxi town (UAV-0.2m), Longxi River (UAV), 0.4883, 0.0128, 0.0250, 0.0126, 0.4231, 0.8340
# Moxi town (UAV-0.2m), Mengdong Township, 0.5221, 0.1876, 0.2760, 0.1601, 0.5305, 0.9027
# Moxi town (UAV-0.2m), Moxi town (UAV-1m), 0.3781, 0.3955, 0.3866, 0.2396, 0.5760, 0.9147
# Moxi town (UAV-0.2m), Moxitaidi (SAT), 0.8328, 0.1870, 0.3054, 0.1803, 0.5624, 0.9452
# Moxi town (UAV-0.2m), Moxitaidi (UAV-0.6m), 0.5051, 0.3100, 0.3842, 0.2378, 0.5734, 0.9115
# Moxi town (UAV-0.2m), Moxitaidi (UAV-1m), 0.4064, 0.3304, 0.3645, 0.2229, 0.5666, 0.9125
# Moxi town (UAV-0.2m), palu, 0.0011, 0.0013, 0.0012, 0.0006, 0.4880, 0.9754
# Moxi town (UAV-0.2m), Tiburon Peninsula (planet), 0.4707, 0.5446, 0.5050, 0.3378, 0.6308, 0.9267
# Moxi town (UAV-0.2m), Tiburon Peninsula (Sentinel), 0.2177, 0.0359, 0.0617, 0.0318, 0.4965, 0.9611
# Moxi town (UAV-0.2m), Wenchuan, 0.2856, 0.3372, 0.3093, 0.1829, 0.5567, 0.9316
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Moxi town (UAV-1m), 1, 1.687, 1.754, 0.0000, 0.0000, 0.0000, 0.0000, 0.4577, 0.9154
# Moxi town (UAV-1m), 2, 1.667, 1.749, 0.0000, 0.0000, 0.0000, 0.0000, 0.4577, 0.9154
# Moxi town (UAV-1m), 3, 1.641, 1.735, 0.0000, 0.0000, 0.0000, 0.0000, 0.4577, 0.9154
# Moxi town (UAV-1m), 4, 1.600, 1.707, 0.0000, 0.0000, 0.0000, 0.0000, 0.4577, 0.9154
# Moxi town (UAV-1m), 5, 1.542, 1.655, 0.0000, 0.0000, 0.0000, 0.0000, 0.4577, 0.9154
# Moxi town (UAV-1m), 6, 1.454, 1.691, 0.0000, 0.0000, 0.0000, 0.0000, 0.4577, 0.9154
# Moxi town (UAV-1m), 7, 1.370, 1.888, 0.0000, 0.0000, 0.0000, 0.0000, 0.4577, 0.9154
# Moxi town (UAV-1m), 8, 1.321, 1.694, 0.0000, 0.0000, 0.0000, 0.0000, 0.4577, 0.9154
# Moxi town (UAV-1m), 9, 1.266, 2.910, 0.0000, 0.0000, 0.0000, 0.0000, 0.4577, 0.9154
# Moxi town (UAV-1m), 10, 1.268, 1.760, 0.0000, 0.0000, 0.0000, 0.0000, 0.4577, 0.9154
# Moxi town (UAV-1m), 11, 1.192, 1.396, 0.3735, 0.0771, 0.1278, 0.0682, 0.4893, 0.9110
# Moxi town (UAV-1m), 12, 1.165, 1.347, 0.3397, 0.3829, 0.3600, 0.2195, 0.5502, 0.8848
# Moxi town (UAV-1m), 13, 1.131, 1.389, 0.2935, 0.5250, 0.3765, 0.2319, 0.5389, 0.8528
# Moxi town (UAV-1m), 14, 1.072, 1.400, 0.2865, 0.6344, 0.3947, 0.2459, 0.5360, 0.8354
# Moxi town (UAV-1m), 15, 1.072, 1.385, 0.2709, 0.7335, 0.3957, 0.2466, 0.5222, 0.8104
# Moxi town (UAV-1m), 16, 1.003, 1.313, 0.3301, 0.8077, 0.4687, 0.3061, 0.5699, 0.8451
# Moxi town (UAV-1m), 17, 0.963, 1.356, 0.2670, 0.8276, 0.4037, 0.2529, 0.5152, 0.7931
# Moxi town (UAV-1m), 18, 0.899, 1.029, 0.4108, 0.8511, 0.5542, 0.3833, 0.6292, 0.8841
# Moxi town (UAV-1m), 19, 0.824, 0.762, 0.5999, 0.8087, 0.6888, 0.5253, 0.7295, 0.9382
# Moxi town (UAV-1m), 20, 0.781, 1.001, 0.4044, 0.8908, 0.5563, 0.3853, 0.6276, 0.8797
# Moxi town (UAV-1m), 21, 0.747, 0.656, 0.6414, 0.8265, 0.7223, 0.5653, 0.7537, 0.9462
# Moxi town (UAV-1m), 22, 0.711, 0.671, 0.5966, 0.8619, 0.7051, 0.5445, 0.7394, 0.9390
# Moxi town (UAV-1m), 23, 0.699, 0.914, 0.4069, 0.9162, 0.5635, 0.3923, 0.6311, 0.8799
# Moxi town (UAV-1m), 24, 0.628, 0.611, 0.6324, 0.8727, 0.7334, 0.5790, 0.7605, 0.9463
# Moxi town (UAV-1m), 25, 0.603, 0.583, 0.6361, 0.8878, 0.7412, 0.5888, 0.7660, 0.9475
# Moxi town (UAV-1m), 26, 0.603, 0.567, 0.7061, 0.8351, 0.7652, 0.6197, 0.7865, 0.9566
# Moxi town (UAV-1m), 27, 0.622, 0.679, 0.6763, 0.7939, 0.7304, 0.5753, 0.7611, 0.9504
# Moxi town (UAV-1m), 28, 0.570, 0.630, 0.5960, 0.8935, 0.7151, 0.5565, 0.7457, 0.9397
# Moxi town (UAV-1m), 29, 0.507, 0.541, 0.6629, 0.8898, 0.7598, 0.6126, 0.7806, 0.9524
# Moxi town (UAV-1m), 30, 0.483, 0.493, 0.7415, 0.8578, 0.7954, 0.6603, 0.8100, 0.9627
# Moxi town (UAV-1m), 31, 0.436, 0.461, 0.7701, 0.8541, 0.8099, 0.6805, 0.8220, 0.9661
# Moxi town (UAV-1m), 32, 0.417, 0.500, 0.7124, 0.8757, 0.7856, 0.6470, 0.8017, 0.9596
# Moxi town (UAV-1m), 33, 0.393, 0.480, 0.8134, 0.8128, 0.8131, 0.6851, 0.8256, 0.9684
# Moxi town (UAV-1m), 34, 0.386, 0.447, 0.7338, 0.8843, 0.8021, 0.6695, 0.8148, 0.9631
# Moxi town (UAV-1m), 35, 0.385, 0.561, 0.8165, 0.7798, 0.7977, 0.6635, 0.8138, 0.9665
# Moxi town (UAV-1m), 36, 0.378, 0.436, 0.7135, 0.9003, 0.7961, 0.6613, 0.8095, 0.9610
# Moxi town (UAV-1m), 37, 0.365, 0.387, 0.8240, 0.8601, 0.8416, 0.7266, 0.8485, 0.9726
# Moxi town (UAV-1m), 38, 0.346, 0.391, 0.7866, 0.8779, 0.8297, 0.7090, 0.8380, 0.9695
# Moxi town (UAV-1m), 39, 0.350, 0.380, 0.8052, 0.8787, 0.8403, 0.7246, 0.8470, 0.9717
# Moxi town (UAV-1m), 40, 0.308, 0.363, 0.8148, 0.8830, 0.8475, 0.7354, 0.8532, 0.9731
# Moxi town (UAV-1m), Hokkaido Iburi-Tobu, 0.7990, 0.1373, 0.2343, 0.1327, 0.5241, 0.9166
# Moxi town (UAV-1m), Jiuzhai valley (UAV-0.2m), 0.7437, 0.6415, 0.6888, 0.5254, 0.6788, 0.8586
# Moxi town (UAV-1m), Jiuzhai valley (UAV-0.5m), 0.5365, 0.6424, 0.5847, 0.4131, 0.6501, 0.8954
# Moxi town (UAV-1m), Lombok, 0.0988, 0.3794, 0.1567, 0.0850, 0.4796, 0.8756
# Moxi town (UAV-1m), Longxi River (SAT), 0.1457, 0.0016, 0.0031, 0.0016, 0.4508, 0.9002
# Moxi town (UAV-1m), Longxi River (UAV), 0.8607, 0.0691, 0.1279, 0.0683, 0.4551, 0.8437
# Moxi town (UAV-1m), Mengdong Township, 0.5552, 0.3004, 0.3899, 0.2422, 0.5732, 0.9070
# Moxi town (UAV-1m), Moxi town (UAV-0.2m), 0.6212, 0.6141, 0.6176, 0.4468, 0.6570, 0.8801
# Moxi town (UAV-1m), Moxitaidi (SAT), 0.6275, 0.3584, 0.4562, 0.2955, 0.6196, 0.9450
# Moxi town (UAV-1m), Moxitaidi (UAV-0.6m), 0.3306, 0.3603, 0.3448, 0.2083, 0.5412, 0.8781
# Moxi town (UAV-1m), Moxitaidi (UAV-1m), 0.3994, 0.3690, 0.3836, 0.2373, 0.5724, 0.9100
# Moxi town (UAV-1m), palu, 0.0358, 0.0419, 0.0386, 0.0197, 0.4981, 0.9765
# Moxi town (UAV-1m), Tiburon Peninsula (planet), 0.4333, 0.7495, 0.5491, 0.3785, 0.6447, 0.9156
# Moxi town (UAV-1m), Tiburon Peninsula (Sentinel), 0.3509, 0.1436, 0.2038, 0.1135, 0.5367, 0.9601
# Moxi town (UAV-1m), Wenchuan, 0.5166, 0.2514, 0.3382, 0.2035, 0.5791, 0.9553
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Moxitaidi (SAT), 1, 1.695, 1.679, 0.0000, 0.0000, 0.0000, 0.0000, 0.4703, 0.9405
# Moxitaidi (SAT), 2, 1.674, 1.670, 0.0000, 0.0000, 0.0000, 0.0000, 0.4703, 0.9405
# Moxitaidi (SAT), 3, 1.643, 1.647, 0.0000, 0.0000, 0.0000, 0.0000, 0.4703, 0.9405
# Moxitaidi (SAT), 4, 1.592, 1.579, 0.0000, 0.0000, 0.0000, 0.0000, 0.4703, 0.9405
# Moxitaidi (SAT), 5, 1.465, 1.411, 0.0000, 0.0000, 0.0000, 0.0000, 0.4703, 0.9405
# Moxitaidi (SAT), 6, 1.281, 2.403, 0.0000, 0.0000, 0.0000, 0.0000, 0.4703, 0.9405
# Moxitaidi (SAT), 7, 1.181, 2.104, 0.0000, 0.0000, 0.0000, 0.0000, 0.4703, 0.9405
# Moxitaidi (SAT), 8, 1.082, 1.550, 0.0000, 0.0000, 0.0000, 0.0000, 0.4703, 0.9405
# Moxitaidi (SAT), 9, 1.014, 1.035, 0.9558, 0.1262, 0.2229, 0.1254, 0.5364, 0.9477
# Moxitaidi (SAT), 10, 0.951, 1.431, 0.9279, 0.1248, 0.2200, 0.1236, 0.5353, 0.9474
# Moxitaidi (SAT), 11, 0.872, 0.844, 0.7653, 0.5278, 0.6247, 0.4543, 0.7077, 0.9623
# Moxitaidi (SAT), 12, 0.843, 0.761, 0.5286, 0.7638, 0.6248, 0.4543, 0.6986, 0.9454
# Moxitaidi (SAT), 13, 0.818, 0.770, 0.6375, 0.6913, 0.6633, 0.4962, 0.7263, 0.9583
# Moxitaidi (SAT), 14, 0.726, 0.636, 0.6505, 0.7802, 0.7094, 0.5497, 0.7549, 0.9620
# Moxitaidi (SAT), 15, 0.724, 0.781, 0.4385, 0.8517, 0.5789, 0.4074, 0.6649, 0.9263
# Moxitaidi (SAT), 16, 0.679, 0.602, 0.6145, 0.8229, 0.7036, 0.5427, 0.7497, 0.9588
# Moxitaidi (SAT), 17, 0.579, 0.655, 0.5147, 0.8532, 0.6420, 0.4728, 0.7066, 0.9434
# Moxitaidi (SAT), 18, 0.629, 0.648, 0.6913, 0.7156, 0.7033, 0.5423, 0.7524, 0.9641
# Moxitaidi (SAT), 19, 0.525, 0.609, 0.5915, 0.8231, 0.6884, 0.5248, 0.7391, 0.9557
# Moxitaidi (SAT), 20, 0.543, 0.639, 0.7102, 0.7887, 0.7474, 0.5967, 0.7817, 0.9683
# Moxitaidi (SAT), 21, 0.507, 0.659, 0.5374, 0.8307, 0.6526, 0.4844, 0.7145, 0.9474
# Moxitaidi (SAT), 22, 0.483, 0.600, 0.6729, 0.8204, 0.7393, 0.5865, 0.7752, 0.9656
# Moxitaidi (SAT), 23, 0.645, 1.236, 0.3363, 0.8894, 0.4881, 0.3228, 0.6028, 0.8890
# Moxitaidi (SAT), 24, 0.456, 0.695, 0.7154, 0.6554, 0.6841, 0.5198, 0.7412, 0.9640
# Moxitaidi (SAT), 25, 0.588, 0.612, 0.6649, 0.8147, 0.7322, 0.5775, 0.7701, 0.9646
# Moxitaidi (SAT), 26, 0.486, 0.535, 0.7194, 0.7966, 0.7560, 0.6078, 0.7878, 0.9694
# Moxitaidi (SAT), 27, 0.534, 0.606, 0.6366, 0.8171, 0.7157, 0.5572, 0.7583, 0.9614
# Moxitaidi (SAT), 28, 0.452, 0.633, 0.7064, 0.7574, 0.7310, 0.5761, 0.7707, 0.9668
# Moxitaidi (SAT), 29, 0.407, 0.743, 0.4838, 0.8605, 0.6194, 0.4487, 0.6912, 0.9371
# Moxitaidi (SAT), 30, 0.385, 0.565, 0.6189, 0.8368, 0.7115, 0.5522, 0.7549, 0.9596
# Moxitaidi (SAT), 31, 0.341, 0.561, 0.6914, 0.7845, 0.7350, 0.5810, 0.7729, 0.9664
# Moxitaidi (SAT), 32, 0.309, 0.578, 0.5894, 0.8531, 0.6971, 0.5351, 0.7443, 0.9559
# Moxitaidi (SAT), 33, 0.324, 0.587, 0.6630, 0.8306, 0.7374, 0.5840, 0.7735, 0.9648
# Moxitaidi (SAT), 34, 0.287, 0.532, 0.6443, 0.8550, 0.7349, 0.5809, 0.7711, 0.9633
# Moxitaidi (SAT), 35, 0.299, 0.591, 0.7148, 0.8005, 0.7552, 0.6067, 0.7872, 0.9691
# Moxitaidi (SAT), 36, 0.280, 0.578, 0.7428, 0.7888, 0.7651, 0.6196, 0.7947, 0.9712
# Moxitaidi (SAT), 37, 0.256, 0.512, 0.6897, 0.8265, 0.7519, 0.6025, 0.7842, 0.9676
# Moxitaidi (SAT), 38, 0.228, 0.547, 0.7602, 0.7828, 0.7713, 0.6277, 0.7994, 0.9724
# Moxitaidi (SAT), 39, 0.251, 0.540, 0.7104, 0.8197, 0.7611, 0.6144, 0.7911, 0.9694
# Moxitaidi (SAT), 40, 0.254, 0.582, 0.6634, 0.8156, 0.7317, 0.5769, 0.7697, 0.9644
# Moxitaidi (SAT), Hokkaido Iburi-Tobu, 0.6167, 0.0740, 0.1321, 0.0707, 0.4899, 0.9097
# Moxitaidi (SAT), Jiuzhai valley (UAV-0.2m), 0.1210, 0.1904, 0.1479, 0.0799, 0.2593, 0.4648
# Moxitaidi (SAT), Jiuzhai valley (UAV-0.5m), 0.1549, 0.3806, 0.2202, 0.1237, 0.4002, 0.6909
# Moxitaidi (SAT), Lombok, 0.0205, 0.0981, 0.0340, 0.0173, 0.4234, 0.8301
# Moxitaidi (SAT), Longxi River (SAT), 0.2398, 0.8319, 0.3723, 0.2287, 0.4629, 0.7220
# Moxitaidi (SAT), Longxi River (UAV), 0.2444, 0.3921, 0.3012, 0.1773, 0.4271, 0.6980
# Moxitaidi (SAT), Mengdong Township, 0.2596, 0.3816, 0.3090, 0.1827, 0.5037, 0.8312
# Moxitaidi (SAT), Moxi town (UAV-0.2m), 0.3380, 0.3995, 0.3662, 0.2241, 0.4956, 0.7818
# Moxitaidi (SAT), Moxi town (UAV-1m), 0.1665, 0.0386, 0.0627, 0.0324, 0.4768, 0.9215
# Moxitaidi (SAT), Moxitaidi (UAV-0.6m), 0.1751, 0.7649, 0.2850, 0.1662, 0.3997, 0.6582
# Moxitaidi (SAT), Moxitaidi (UAV-1m), 0.2111, 0.6290, 0.3161, 0.1877, 0.4854, 0.7933
# Moxitaidi (SAT), palu, 0.0056, 0.0199, 0.0087, 0.0044, 0.4766, 0.9488
# Moxitaidi (SAT), Tiburon Peninsula (planet), 0.3735, 0.2083, 0.2675, 0.1544, 0.5375, 0.9217
# Moxitaidi (SAT), Tiburon Peninsula (Sentinel), 0.1324, 0.0272, 0.0452, 0.0231, 0.4911, 0.9591
# Moxitaidi (SAT), Wenchuan, 0.1176, 0.6257, 0.1980, 0.1099, 0.4364, 0.7696
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Moxitaidi (UAV-0.6m), 1, 1.725, 1.747, 0.0000, 0.0000, 0.0000, 0.0000, 0.4522, 0.9044
# Moxitaidi (UAV-0.6m), 2, 1.700, 1.739, 0.0000, 0.0000, 0.0000, 0.0000, 0.4522, 0.9044
# Moxitaidi (UAV-0.6m), 3, 1.675, 1.725, 0.0000, 0.0000, 0.0000, 0.0000, 0.4522, 0.9044
# Moxitaidi (UAV-0.6m), 4, 1.641, 1.697, 0.0000, 0.0000, 0.0000, 0.0000, 0.4522, 0.9044
# Moxitaidi (UAV-0.6m), 5, 1.581, 1.628, 0.0000, 0.0000, 0.0000, 0.0000, 0.4522, 0.9044
# Moxitaidi (UAV-0.6m), 6, 1.466, 1.942, 0.0000, 0.0000, 0.0000, 0.0000, 0.4522, 0.9044
# Moxitaidi (UAV-0.6m), 7, 1.396, 1.489, 0.0000, 0.0000, 0.0000, 0.0000, 0.4522, 0.9044
# Moxitaidi (UAV-0.6m), 8, 1.295, 1.445, 0.0000, 0.0000, 0.0000, 0.0000, 0.4522, 0.9044
# Moxitaidi (UAV-0.6m), 9, 1.275, 1.470, 0.4855, 0.0546, 0.0982, 0.0516, 0.4776, 0.9041
# Moxitaidi (UAV-0.6m), 10, 1.222, 1.393, 0.2759, 0.2754, 0.2757, 0.1599, 0.5089, 0.8616
# Moxitaidi (UAV-0.6m), 11, 1.193, 1.316, 0.3847, 0.3096, 0.3431, 0.2070, 0.5451, 0.8867
# Moxitaidi (UAV-0.6m), 12, 1.092, 1.353, 0.4654, 0.2944, 0.3606, 0.2200, 0.5587, 0.9002
# Moxitaidi (UAV-0.6m), 13, 1.062, 1.224, 0.4013, 0.4614, 0.4293, 0.2733, 0.5753, 0.8827
# Moxitaidi (UAV-0.6m), 14, 1.058, 1.275, 0.4356, 0.4577, 0.4464, 0.2873, 0.5869, 0.8915
# Moxitaidi (UAV-0.6m), 15, 1.046, 1.221, 0.3781, 0.5945, 0.4623, 0.3006, 0.5802, 0.8678
# Moxitaidi (UAV-0.6m), 16, 0.960, 1.252, 0.5040, 0.4535, 0.4774, 0.3136, 0.6072, 0.9051
# Moxitaidi (UAV-0.6m), 17, 0.976, 1.129, 0.4505, 0.5739, 0.5048, 0.3376, 0.6118, 0.8923
# Moxitaidi (UAV-0.6m), 18, 0.905, 1.238, 0.4845, 0.5134, 0.4986, 0.3321, 0.6141, 0.9013
# Moxitaidi (UAV-0.6m), 19, 0.874, 1.398, 0.4599, 0.5450, 0.4989, 0.3323, 0.6109, 0.8953
# Moxitaidi (UAV-0.6m), 20, 0.881, 1.179, 0.4569, 0.6042, 0.5204, 0.3517, 0.6193, 0.8935
# Moxitaidi (UAV-0.6m), 21, 0.793, 1.245, 0.5693, 0.4486, 0.5018, 0.3350, 0.6230, 0.9148
# ...
# palu, 39, 0.656, 0.960, 0.0766, 0.2280, 0.1146, 0.0608, 0.5185, 0.9762
# palu, 40, 0.607, 0.826, 0.1115, 0.4262, 0.1767, 0.0969, 0.5350, 0.9731
# palu, Hokkaido Iburi-Tobu, 0.6969, 0.0900, 0.1595, 0.0866, 0.4988, 0.9118
# palu, Jiuzhai valley (UAV-0.2m), 0.7877, 0.0571, 0.1065, 0.0562, 0.4095, 0.7662
# palu, Jiuzhai valley (UAV-0.5m), 0.5725, 0.1112, 0.1862, 0.1027, 0.4949, 0.8886
# palu, Lombok, 0.2652, 0.0776, 0.1201, 0.0639, 0.5146, 0.9653
# palu, Longxi River (SAT), 0.0000, 0.0000, 0.0000, 0.0000, 0.4504, 0.9008
# palu, Longxi River (UAV), 0.5940, 0.0041, 0.0081, 0.0041, 0.4191, 0.8343
# palu, Mengdong Township, 0.1541, 0.0023, 0.0045, 0.0023, 0.4512, 0.9001
# palu, Moxi town (UAV-0.2m), 0.2597, 0.0601, 0.0976, 0.0513, 0.4372, 0.8247
# palu, Moxi town (UAV-1m), 0.1687, 0.3292, 0.2231, 0.1256, 0.4831, 0.8442
# palu, Moxitaidi (SAT), 0.2279, 0.0352, 0.0610, 0.0315, 0.4808, 0.9302
# palu, Moxitaidi (UAV-0.6m), 0.2776, 0.0067, 0.0131, 0.0066, 0.4583, 0.9100
# palu, Moxitaidi (UAV-1m), 0.0601, 0.0100, 0.0171, 0.0086, 0.4608, 0.9130
# palu, Tiburon Peninsula (planet), 0.4563, 0.0857, 0.1444, 0.0778, 0.5038, 0.9303
# palu, Tiburon Peninsula (Sentinel), 0.2355, 0.1827, 0.2057, 0.1147, 0.5321, 0.9499
# palu, Wenchuan, 0.4879, 0.3119, 0.3805, 0.2350, 0.5941, 0.9539
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Tiburon Peninsula (planet), 1, 1.709, 1.707, 0.0000, 0.0000, 0.0000, 0.0000, 0.4685, 0.9369
# Tiburon Peninsula (planet), 2, 1.674, 1.691, 0.0000, 0.0000, 0.0000, 0.0000, 0.4685, 0.9369
# Tiburon Peninsula (planet), 3, 1.635, 1.662, 0.0000, 0.0000, 0.0000, 0.0000, 0.4685, 0.9369
# Tiburon Peninsula (planet), 4, 1.575, 1.602, 0.0000, 0.0000, 0.0000, 0.0000, 0.4685, 0.9369
# Tiburon Peninsula (planet), 5, 1.473, 1.427, 0.0000, 0.0000, 0.0000, 0.0000, 0.4685, 0.9369
# Tiburon Peninsula (planet), 6, 1.281, 2.908, 0.0000, 0.0000, 0.0000, 0.0000, 0.4685, 0.9369
# Tiburon Peninsula (planet), 7, 1.175, 1.949, 0.0000, 0.0000, 0.0000, 0.0000, 0.4685, 0.9369
# Tiburon Peninsula (planet), 8, 1.098, 1.583, 0.0216, 0.0131, 0.0163, 0.0082, 0.4543, 0.9005
# Tiburon Peninsula (planet), 9, 1.041, 1.187, 0.2142, 0.2061, 0.2101, 0.1174, 0.5092, 0.9022
# Tiburon Peninsula (planet), 10, 1.013, 1.022, 0.3317, 0.4173, 0.3696, 0.2267, 0.5672, 0.9102
# Tiburon Peninsula (planet), 11, 0.938, 0.859, 0.8361, 0.3136, 0.4561, 0.2954, 0.6236, 0.9528
# Tiburon Peninsula (planet), 12, 0.862, 0.693, 0.7439, 0.6627, 0.7010, 0.5396, 0.7512, 0.9643
# Tiburon Peninsula (planet), 13, 0.820, 0.605, 0.7623, 0.6806, 0.7192, 0.5615, 0.7632, 0.9665
# Tiburon Peninsula (planet), 14, 0.743, 0.642, 0.7802, 0.6253, 0.6942, 0.5316, 0.7477, 0.9653
# Tiburon Peninsula (planet), 15, 0.691, 0.568, 0.6058, 0.8436, 0.7052, 0.5447, 0.7488, 0.9555
# Tiburon Peninsula (planet), 16, 0.691, 0.508, 0.6655, 0.8299, 0.7387, 0.5857, 0.7733, 0.9630
# Tiburon Peninsula (planet), 17, 0.752, 0.693, 0.4652, 0.8811, 0.6089, 0.4377, 0.6811, 0.9286
# Tiburon Peninsula (planet), 18, 0.687, 0.491, 0.6518, 0.8417, 0.7347, 0.5806, 0.7701, 0.9617
# Tiburon Peninsula (planet), 19, 0.688, 0.466, 0.6913, 0.8365, 0.7570, 0.6090, 0.7866, 0.9661
# Tiburon Peninsula (planet), 20, 0.635, 0.530, 0.5924, 0.8777, 0.7074, 0.5472, 0.7494, 0.9542
# Tiburon Peninsula (planet), 21, 0.615, 0.458, 0.6812, 0.8337, 0.7498, 0.5997, 0.7814, 0.9649
# Tiburon Peninsula (planet), 22, 0.610, 0.459, 0.6707, 0.8623, 0.7545, 0.6058, 0.7842, 0.9646
# Tiburon Peninsula (planet), 23, 0.590, 0.462, 0.6632, 0.8649, 0.7507, 0.6009, 0.7813, 0.9638
# Tiburon Peninsula (planet), 24, 0.559, 0.458, 0.6623, 0.8516, 0.7451, 0.5937, 0.7775, 0.9633
# Tiburon Peninsula (planet), 25, 0.601, 0.401, 0.6986, 0.8593, 0.7707, 0.6269, 0.7964, 0.9677
# Tiburon Peninsula (planet), 26, 0.534, 0.416, 0.7061, 0.8536, 0.7729, 0.6299, 0.7982, 0.9684
# Tiburon Peninsula (planet), 27, 0.548, 0.399, 0.6951, 0.8583, 0.7681, 0.6236, 0.7945, 0.9673
# Tiburon Peninsula (planet), 28, 0.551, 0.384, 0.7595, 0.8165, 0.7870, 0.6488, 0.8097, 0.9721
# Tiburon Peninsula (planet), 29, 0.557, 0.379, 0.7337, 0.8459, 0.7858, 0.6472, 0.8082, 0.9709
# Tiburon Peninsula (planet), 30, 0.568, 0.395, 0.7140, 0.8590, 0.7798, 0.6391, 0.8034, 0.9694
# Tiburon Peninsula (planet), 31, 0.502, 0.463, 0.6203, 0.9058, 0.7363, 0.5827, 0.7697, 0.9591
# Tiburon Peninsula (planet), 32, 0.542, 0.417, 0.7220, 0.8421, 0.7774, 0.6359, 0.8019, 0.9696
# Tiburon Peninsula (planet), 33, 0.519, 0.406, 0.7791, 0.7730, 0.7761, 0.6341, 0.8022, 0.9719
# Tiburon Peninsula (planet), 34, 0.510, 0.378, 0.7613, 0.8188, 0.7890, 0.6516, 0.8112, 0.9724
# Tiburon Peninsula (planet), 35, 0.491, 0.391, 0.7023, 0.8764, 0.7797, 0.6390, 0.8030, 0.9688
# Tiburon Peninsula (planet), 36, 0.521, 0.397, 0.7031, 0.8723, 0.7786, 0.6375, 0.8022, 0.9687
# Tiburon Peninsula (planet), 37, 0.540, 0.368, 0.7587, 0.8354, 0.7952, 0.6600, 0.8157, 0.9729
# Tiburon Peninsula (planet), 38, 0.504, 0.369, 0.7440, 0.8514, 0.7941, 0.6585, 0.8145, 0.9722
# Tiburon Peninsula (planet), 39, 0.488, 0.398, 0.6911, 0.8877, 0.7771, 0.6355, 0.8007, 0.9679
# Tiburon Peninsula (planet), 40, 0.464, 0.383, 0.7201, 0.8658, 0.7863, 0.6478, 0.8082, 0.9703
# Tiburon Peninsula (planet), Hokkaido Iburi-Tobu, 0.4006, 0.7679, 0.5265, 0.3573, 0.6095, 0.8716
# Tiburon Peninsula (planet), Jiuzhai valley (UAV-0.2m), 0.6609, 0.6830, 0.6718, 0.5058, 0.6552, 0.8371
# Tiburon Peninsula (planet), Jiuzhai valley (UAV-0.5m), 0.4582, 0.7882, 0.5796, 0.4080, 0.6319, 0.8689
# Tiburon Peninsula (planet), Lombok, 0.1229, 0.6937, 0.2088, 0.1166, 0.4764, 0.8398
# Tiburon Peninsula (planet), Longxi River (SAT), 0.7730, 0.0367, 0.0700, 0.0363, 0.4697, 0.9035
# Tiburon Peninsula (planet), Longxi River (UAV), 0.4633, 0.1519, 0.2288, 0.1292, 0.4774, 0.8301
# Tiburon Peninsula (planet), Mengdong Township, 0.1747, 0.4190, 0.2466, 0.1406, 0.4383, 0.7468
# Tiburon Peninsula (planet), Moxi town (UAV-0.2m), 0.2549, 0.8269, 0.3897, 0.2420, 0.3861, 0.5914
# Tiburon Peninsula (planet), Moxi town (UAV-1m), 0.1582, 0.8879, 0.2686, 0.1551, 0.4027, 0.6713
# Tiburon Peninsula (planet), Moxitaidi (SAT), 0.3410, 0.6260, 0.4415, 0.2833, 0.5885, 0.8980
# Tiburon Peninsula (planet), Moxitaidi (UAV-0.6m), 0.2296, 0.5304, 0.3204, 0.1908, 0.4903, 0.7997
# Tiburon Peninsula (planet), Moxitaidi (UAV-1m), 0.1855, 0.6729, 0.2908, 0.1702, 0.4538, 0.7509
# Tiburon Peninsula (planet), palu, 0.1046, 0.4567, 0.1702, 0.0930, 0.5213, 0.9499
# Tiburon Peninsula (planet), Tiburon Peninsula (Sentinel), 0.2309, 0.5292, 0.3216, 0.1916, 0.5553, 0.9206
# Tiburon Peninsula (planet), Wenchuan, 0.3802, 0.6081, 0.4678, 0.3053, 0.6203, 0.9371
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Tiburon Peninsula (Sentinel), 1, 1.650, 1.642, 0.0000, 0.0000, 0.0000, 0.0000, 0.4843, 0.9686
# Tiburon Peninsula (Sentinel), 2, 1.623, 1.626, 0.0000, 0.0000, 0.0000, 0.0000, 0.4843, 0.9686
# Tiburon Peninsula (Sentinel), 3, 1.587, 1.594, 0.0000, 0.0000, 0.0000, 0.0000, 0.4843, 0.9686
# Tiburon Peninsula (Sentinel), 4, 1.531, 1.518, 0.0000, 0.0000, 0.0000, 0.0000, 0.4843, 0.9686
# Tiburon Peninsula (Sentinel), 5, 1.434, 1.270, 0.0000, 0.0000, 0.0000, 0.0000, 0.4843, 0.9686
# Tiburon Peninsula (Sentinel), 6, 1.313, 1.523, 0.0000, 0.0000, 0.0000, 0.0000, 0.4843, 0.9686
# Tiburon Peninsula (Sentinel), 7, 1.183, 1.127, 0.0000, 0.0000, 0.0000, 0.0000, 0.4843, 0.9686
# Tiburon Peninsula (Sentinel), 8, 1.136, 1.048, 0.0000, 0.0000, 0.0000, 0.0000, 0.4843, 0.9686
# Tiburon Peninsula (Sentinel), 9, 1.043, 1.005, 0.0000, 0.0000, 0.0000, 0.0000, 0.4843, 0.9686
# Tiburon Peninsula (Sentinel), 10, 0.996, 0.964, 0.6256, 0.0598, 0.1092, 0.0578, 0.5135, 0.9694
# Tiburon Peninsula (Sentinel), 11, 0.925, 0.924, 0.5880, 0.2563, 0.3570, 0.2173, 0.5940, 0.9710
# Tiburon Peninsula (Sentinel), 12, 0.901, 0.889, 0.5621, 0.4389, 0.4929, 0.3271, 0.6492, 0.9717
# Tiburon Peninsula (Sentinel), 13, 0.933, 0.879, 0.5156, 0.5707, 0.5418, 0.3715, 0.6703, 0.9697
# Tiburon Peninsula (Sentinel), 14, 0.854, 0.856, 0.5309, 0.6130, 0.5690, 0.3976, 0.6840, 0.9709
# Tiburon Peninsula (Sentinel), 15, 0.825, 0.912, 0.3712, 0.7683, 0.5006, 0.3339, 0.6423, 0.9519
# Tiburon Peninsula (Sentinel), 16, 0.854, 0.858, 0.4316, 0.7240, 0.5408, 0.3706, 0.6656, 0.9614
# Tiburon Peninsula (Sentinel), 17, 0.835, 0.876, 0.5108, 0.6609, 0.5762, 0.4047, 0.6868, 0.9695
# Tiburon Peninsula (Sentinel), 18, 0.772, 0.840, 0.4435, 0.7598, 0.5601, 0.3890, 0.6753, 0.9626
# Tiburon Peninsula (Sentinel), 19, 0.721, 0.818, 0.4572, 0.7430, 0.5661, 0.3948, 0.6791, 0.9643
# Tiburon Peninsula (Sentinel), 20, 0.788, 0.820, 0.4384, 0.7636, 0.5570, 0.3860, 0.6735, 0.9619
# Tiburon Peninsula (Sentinel), 21, 0.717, 0.862, 0.5849, 0.6349, 0.6089, 0.4377, 0.7058, 0.9744
# Tiburon Peninsula (Sentinel), 22, 0.746, 0.823, 0.4352, 0.7649, 0.5548, 0.3839, 0.6722, 0.9615
# Tiburon Peninsula (Sentinel), 23, 0.670, 0.786, 0.4834, 0.7374, 0.5840, 0.4124, 0.6893, 0.9670
# Tiburon Peninsula (Sentinel), 24, 0.721, 0.814, 0.4722, 0.7630, 0.5834, 0.4118, 0.6884, 0.9658
# Tiburon Peninsula (Sentinel), 25, 0.755, 0.852, 0.4672, 0.7517, 0.5762, 0.4047, 0.6846, 0.9653
# Tiburon Peninsula (Sentinel), 26, 0.714, 0.855, 0.5538, 0.6654, 0.6045, 0.4332, 0.7026, 0.9727
# Tiburon Peninsula (Sentinel), 27, 0.686, 0.820, 0.4372, 0.7758, 0.5592, 0.3881, 0.6744, 0.9616
# Tiburon Peninsula (Sentinel), 28, 0.589, 0.784, 0.5111, 0.7424, 0.6054, 0.4341, 0.7015, 0.9696
# Tiburon Peninsula (Sentinel), 29, 0.554, 0.777, 0.6301, 0.6479, 0.6389, 0.4694, 0.7230, 0.9770
# Tiburon Peninsula (Sentinel), 30, 0.546, 0.758, 0.5147, 0.7622, 0.6144, 0.4435, 0.7064, 0.9700
# Tiburon Peninsula (Sentinel), 31, 0.541, 0.791, 0.5713, 0.6982, 0.6284, 0.4581, 0.7158, 0.9741
# Tiburon Peninsula (Sentinel), 32, 0.510, 0.861, 0.5938, 0.6934, 0.6397, 0.4703, 0.7226, 0.9755
# Tiburon Peninsula (Sentinel), 33, 0.464, 0.737, 0.5899, 0.7171, 0.6473, 0.4785, 0.7267, 0.9755
# Tiburon Peninsula (Sentinel), 34, 0.449, 0.722, 0.5611, 0.7615, 0.6461, 0.4773, 0.7252, 0.9738
# Tiburon Peninsula (Sentinel), 35, 0.435, 0.700, 0.6541, 0.6829, 0.6682, 0.5017, 0.7400, 0.9787
# Tiburon Peninsula (Sentinel), 36, 0.416, 0.701, 0.6420, 0.6938, 0.6669, 0.5003, 0.7390, 0.9783
# Tiburon Peninsula (Sentinel), 37, 0.402, 0.704, 0.6678, 0.6680, 0.6679, 0.5014, 0.7401, 0.9792
# Tiburon Peninsula (Sentinel), 38, 0.379, 0.799, 0.6167, 0.7240, 0.6661, 0.4993, 0.7380, 0.9772
# Tiburon Peninsula (Sentinel), 39, 0.416, 0.766, 0.5898, 0.7417, 0.6571, 0.4893, 0.7322, 0.9757
# Tiburon Peninsula (Sentinel), 40, 0.369, 0.699, 0.6299, 0.7051, 0.6654, 0.4986, 0.7379, 0.9778
# Tiburon Peninsula (Sentinel), Hokkaido Iburi-Tobu, 0.4014, 0.0093, 0.0181, 0.0092, 0.4578, 0.9066
# Tiburon Peninsula (Sentinel), Jiuzhai valley (UAV-0.2m), 0.8256, 0.2211, 0.3488, 0.2113, 0.4991, 0.7985
# Tiburon Peninsula (Sentinel), Jiuzhai valley (UAV-0.5m), 0.7580, 0.2984, 0.4282, 0.2724, 0.5889, 0.9086
# Tiburon Peninsula (Sentinel), Lombok, 0.3611, 0.1497, 0.2117, 0.1184, 0.5421, 0.9660
# Tiburon Peninsula (Sentinel), Longxi River (SAT), 0.0000, 0.0000, 0.0000, 0.0000, 0.4502, 0.9005
# Tiburon Peninsula (Sentinel), Longxi River (UAV), 0.5444, 0.0071, 0.0141, 0.0071, 0.4206, 0.8343
# Tiburon Peninsula (Sentinel), Mengdong Township, 0.1527, 0.0088, 0.0167, 0.0084, 0.4527, 0.8971
# Tiburon Peninsula (Sentinel), Moxi town (UAV-0.2m), 0.2902, 0.0784, 0.1235, 0.0658, 0.4440, 0.8244
# Tiburon Peninsula (Sentinel), Moxi town (UAV-1m), 0.1560, 0.5615, 0.2442, 0.1391, 0.4467, 0.7637
# Tiburon Peninsula (Sentinel), Moxitaidi (SAT), 0.1334, 0.0201, 0.0350, 0.0178, 0.4731, 0.9285
# Tiburon Peninsula (Sentinel), Moxitaidi (UAV-0.6m), 0.0795, 0.0156, 0.0261, 0.0132, 0.4547, 0.8962
# Tiburon Peninsula (Sentinel), Moxitaidi (UAV-1m), 0.0446, 0.0362, 0.0400, 0.0204, 0.4440, 0.8681
# Tiburon Peninsula (Sentinel), palu, 0.2584, 0.1241, 0.1677, 0.0915, 0.5388, 0.9861
# Tiburon Peninsula (Sentinel), Tiburon Peninsula (planet), 0.6869, 0.3511, 0.4647, 0.3027, 0.6229, 0.9445
# Tiburon Peninsula (Sentinel), Wenchuan, 0.4925, 0.4051, 0.4446, 0.2858, 0.6195, 0.9540
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Wenchuan, 1, 1.762, 1.757, 0.0000, 0.0000, 0.0000, 0.0000, 0.4764, 0.9528
# Wenchuan, 2, 1.712, 1.734, 0.0000, 0.0000, 0.0000, 0.0000, 0.4764, 0.9528
# Wenchuan, 3, 1.656, 1.686, 0.0000, 0.0000, 0.0000, 0.0000, 0.4764, 0.9528
# Wenchuan, 4, 1.572, 1.580, 0.0000, 0.0000, 0.0000, 0.0000, 0.4764, 0.9528
# Wenchuan, 5, 1.395, 1.309, 0.0000, 0.0000, 0.0000, 0.0000, 0.4764, 0.9528
# Wenchuan, 6, 1.104, 1.480, 0.8637, 0.0901, 0.1631, 0.0888, 0.5225, 0.9564
# Wenchuan, 7, 0.985, 0.966, 0.6528, 0.4214, 0.5122, 0.3442, 0.6528, 0.9621
# Wenchuan, 8, 0.884, 0.787, 0.5878, 0.6151, 0.6011, 0.4297, 0.6950, 0.9615
# Wenchuan, 9, 0.882, 0.783, 0.4825, 0.7749, 0.5947, 0.4232, 0.6857, 0.9501
# Wenchuan, 10, 0.841, 0.700, 0.5607, 0.6915, 0.6193, 0.4485, 0.7035, 0.9599
# Wenchuan, 11, 0.816, 0.688, 0.5539, 0.7210, 0.6265, 0.4561, 0.7071, 0.9594
# Wenchuan, 12, 0.765, 0.661, 0.5586, 0.7319, 0.6337, 0.4638, 0.7112, 0.9600
# Wenchuan, 13, 0.772, 0.665, 0.6187, 0.6546, 0.6361, 0.4664, 0.7150, 0.9646
# Wenchuan, 14, 0.750, 0.692, 0.4607, 0.8497, 0.5974, 0.4260, 0.6848, 0.9459
# Wenchuan, 15, 0.810, 0.686, 0.4592, 0.8519, 0.5968, 0.4253, 0.6843, 0.9456
# Wenchuan, 16, 0.755, 0.630, 0.5723, 0.7501, 0.6492, 0.4806, 0.7205, 0.9617
# Wenchuan, 17, 0.721, 0.635, 0.5900, 0.7322, 0.6535, 0.4853, 0.7237, 0.9633
# Wenchuan, 18, 0.736, 0.651, 0.5289, 0.8014, 0.6373, 0.4676, 0.7114, 0.9569
# Wenchuan, 19, 0.726, 0.621, 0.5900, 0.7462, 0.6590, 0.4914, 0.7268, 0.9635
# Wenchuan, 20, 0.688, 0.620, 0.5692, 0.7791, 0.6578, 0.4901, 0.7252, 0.9617
# Wenchuan, 21, 0.696, 0.643, 0.5205, 0.8176, 0.6361, 0.4663, 0.7102, 0.9558
# Wenchuan, 22, 0.717, 0.636, 0.6430, 0.6569, 0.6499, 0.4814, 0.7234, 0.9666
# Wenchuan, 23, 0.717, 0.649, 0.4945, 0.8237, 0.6179, 0.4471, 0.6985, 0.9519
# Wenchuan, 24, 0.742, 0.617, 0.5920, 0.7367, 0.6565, 0.4886, 0.7255, 0.9636
# Wenchuan, 25, 0.683, 0.686, 0.7295, 0.6004, 0.6587, 0.4911, 0.7304, 0.9706
# Wenchuan, 26, 0.669, 0.614, 0.6262, 0.7342, 0.6759, 0.5105, 0.7380, 0.9668
# Wenchuan, 27, 0.667, 0.607, 0.5939, 0.7721, 0.6714, 0.5053, 0.7341, 0.9643
# Wenchuan, 28, 0.628, 0.671, 0.7480, 0.5646, 0.6435, 0.4744, 0.7220, 0.9705
# Wenchuan, 29, 0.602, 0.593, 0.5834, 0.7910, 0.6715, 0.5055, 0.7338, 0.9635
# Wenchuan, 30, 0.611, 0.575, 0.6499, 0.7376, 0.6910, 0.5278, 0.7478, 0.9688
# Wenchuan, 31, 0.588, 0.595, 0.6660, 0.6972, 0.6813, 0.5166, 0.7424, 0.9692
# Wenchuan, 32, 0.548, 0.602, 0.6602, 0.6979, 0.6785, 0.5135, 0.7406, 0.9688
# Wenchuan, 33, 0.540, 0.624, 0.6523, 0.7136, 0.6816, 0.5170, 0.7422, 0.9685
# Wenchuan, 34, 0.524, 0.602, 0.5903, 0.7565, 0.6631, 0.4960, 0.7292, 0.9637
# Wenchuan, 35, 0.489, 0.653, 0.6920, 0.6336, 0.6615, 0.4942, 0.7313, 0.9694
# Wenchuan, 36, 0.488, 0.601, 0.6641, 0.6811, 0.6725, 0.5066, 0.7371, 0.9687
# Wenchuan, 37, 0.512, 0.608, 0.6705, 0.6723, 0.6714, 0.5054, 0.7366, 0.9689
# Wenchuan, 38, 0.447, 0.647, 0.6769, 0.6467, 0.6615, 0.4942, 0.7310, 0.9687
# Wenchuan, 39, 0.473, 0.658, 0.6886, 0.6210, 0.6531, 0.4848, 0.7264, 0.9688
# Wenchuan, 40, 0.439, 0.629, 0.6619, 0.6665, 0.6642, 0.4972, 0.7322, 0.9682
# Wenchuan, Hokkaido Iburi-Tobu, 0.5000, 0.3076, 0.3809, 0.2352, 0.5698, 0.9071
# Wenchuan, Jiuzhai valley (UAV-0.2m), 0.7362, 0.4989, 0.5947, 0.4232, 0.6172, 0.8341
# Wenchuan, Jiuzhai valley (UAV-0.5m), 0.6078, 0.4104, 0.4900, 0.3245, 0.6108, 0.9020
# Wenchuan, Lombok, 0.0734, 0.2865, 0.1169, 0.0621, 0.4645, 0.8681
# Wenchuan, Longxi River (SAT), 0.2291, 0.0139, 0.0262, 0.0133, 0.4554, 0.8977
# Wenchuan, Longxi River (UAV), 0.6809, 0.2476, 0.3631, 0.2218, 0.5358, 0.8559
# Wenchuan, Mengdong Township, 0.4572, 0.5969, 0.5178, 0.3493, 0.6163, 0.8901
# Wenchuan, Moxi town (UAV-0.2m), 0.2964, 0.2650, 0.2798, 0.1627, 0.4691, 0.7849
# Wenchuan, Moxi town (UAV-1m), 0.1535, 0.4180, 0.2245, 0.1264, 0.4622, 0.8037
# Wenchuan, Moxitaidi (SAT), 0.2703, 0.5157, 0.3547, 0.2156, 0.5453, 0.8791
# Wenchuan, Moxitaidi (UAV-0.6m), 0.2285, 0.3708, 0.2827, 0.1646, 0.4957, 0.8325
# Wenchuan, Moxitaidi (UAV-1m), 0.1890, 0.4114, 0.2590, 0.1487, 0.4821, 0.8213
# Wenchuan, palu, 0.0221, 0.1298, 0.0378, 0.0193, 0.4724, 0.9256
# Wenchuan, Tiburon Peninsula (planet), 0.1145, 0.9161, 0.2036, 0.1134, 0.2943, 0.5083
# Wenchuan, Tiburon Peninsula (Sentinel), 0.2301, 0.3633, 0.2817, 0.1640, 0.5486, 0.9342

# %%
### TARGET ONLY ###

from torch.utils.data import DataLoader
import torch.optim as optim
from sklearn.model_selection import train_test_split

batch_size = 16

output = "target_region,precision,recall,f1,iou,miou,oa"

for target_region in regions_dict:
    image_paths = regions_dict[target_region]
    mask_paths = [f.replace("img", "mask") for f in image_paths]

    train_img, temp_img, train_mask, temp_mask = train_test_split(
        image_paths, mask_paths, test_size=.3, random_state=42
    )
    
    val_img, test_img, val_mask, test_mask = train_test_split(
        temp_img, temp_mask, test_size=.5, random_state=42
    )

    train_dataset = LandslideDataset(train_img, train_mask)
    val_dataset = LandslideDataset(val_img, val_mask)
    test_dataset = LandslideDataset(test_img, test_mask)

    trainLoader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=torch.cuda.is_available())
    valLoader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=torch.cuda.is_available())
    testLoader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=torch.cuda.is_available())

    epochs = 40

    model = ResNetUNet()
    model.to(device)

    optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)

    model_path = "../../models/baseline/target_only/" + target_region + ".pth"

    train_model(model, optimizer, trainLoader, valLoader, epochs, model_path, target_region)

    model.load_state_dict(torch.load(model_path, map_location=device))
    
    precision, recall, f1, iou, miou, oa = test_model(model, testLoader)
    result = f'{target_region}, {precision:.4f}, {recall:.4f}, {f1:.4f}, {iou:.4f}, {miou:.4f}, {oa:.4f}'
    print(result)
    output += f'\n{result}'
    
with open("../../results/baseline/target_only.csv", "w") as f:
    f.write(output)
# Out:
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Hokkaido Iburi-Tobu, 1, 1.751, 1.697, 0.0000, 0.0000, 0.0000, 0.0000, 0.4742, 0.9485
# Hokkaido Iburi-Tobu, 2, 1.730, 1.691, 0.0000, 0.0000, 0.0000, 0.0000, 0.4742, 0.9485
# Hokkaido Iburi-Tobu, 3, 1.707, 1.681, 0.0000, 0.0000, 0.0000, 0.0000, 0.4742, 0.9485
# Hokkaido Iburi-Tobu, 4, 1.677, 1.656, 0.0000, 0.0000, 0.0000, 0.0000, 0.4742, 0.9485
# Hokkaido Iburi-Tobu, 5, 1.610, 1.524, 0.0000, 0.0000, 0.0000, 0.0000, 0.4742, 0.9485
# Hokkaido Iburi-Tobu, 6, 1.443, 2.428, 0.0000, 0.0000, 0.0000, 0.0000, 0.4742, 0.9485
# Hokkaido Iburi-Tobu, 7, 1.221, 3.319, 0.8056, 0.0436, 0.0828, 0.0432, 0.4966, 0.9502
# Hokkaido Iburi-Tobu, 8, 1.032, 1.502, 0.8163, 0.3529, 0.4928, 0.3269, 0.6444, 0.9626
# Hokkaido Iburi-Tobu, 9, 0.943, 0.881, 0.7352, 0.6247, 0.6754, 0.5099, 0.7390, 0.9691
# Hokkaido Iburi-Tobu, 10, 0.821, 0.769, 0.6222, 0.7815, 0.6928, 0.5300, 0.7464, 0.9643
# Hokkaido Iburi-Tobu, 11, 0.792, 0.846, 0.4837, 0.8723, 0.6223, 0.4517, 0.6973, 0.9454
# Hokkaido Iburi-Tobu, 12, 0.720, 0.706, 0.5235, 0.8585, 0.6504, 0.4819, 0.7161, 0.9524
# Hokkaido Iburi-Tobu, 13, 0.853, 0.626, 0.5711, 0.8380, 0.6793, 0.5143, 0.7359, 0.9592
# Hokkaido Iburi-Tobu, 14, 0.728, 0.589, 0.6963, 0.7417, 0.7183, 0.5604, 0.7646, 0.9700
# Hokkaido Iburi-Tobu, 15, 0.789, 0.656, 0.5180, 0.8502, 0.6437, 0.4746, 0.7120, 0.9515
# Hokkaido Iburi-Tobu, 16, 0.778, 0.565, 0.6533, 0.7958, 0.7176, 0.5595, 0.7629, 0.9677
# Hokkaido Iburi-Tobu, 17, 0.747, 0.570, 0.7324, 0.7376, 0.7350, 0.5810, 0.7763, 0.9726
# Hokkaido Iburi-Tobu, 18, 0.696, 0.578, 0.6356, 0.8278, 0.7191, 0.5614, 0.7633, 0.9667
# Hokkaido Iburi-Tobu, 19, 0.721, 0.559, 0.6435, 0.8035, 0.7147, 0.5560, 0.7608, 0.9669
# Hokkaido Iburi-Tobu, 20, 0.687, 0.556, 0.6709, 0.7763, 0.7197, 0.5622, 0.7649, 0.9688
# Hokkaido Iburi-Tobu, 21, 0.650, 0.541, 0.6836, 0.7869, 0.7316, 0.5768, 0.7729, 0.9703
# Hokkaido Iburi-Tobu, 22, 0.703, 0.580, 0.5918, 0.8522, 0.6985, 0.5367, 0.7485, 0.9621
# Hokkaido Iburi-Tobu, 23, 0.660, 0.560, 0.6581, 0.7939, 0.7197, 0.5621, 0.7644, 0.9681
# Hokkaido Iburi-Tobu, 24, 0.655, 0.620, 0.5262, 0.8343, 0.6453, 0.4764, 0.7135, 0.9527
# Hokkaido Iburi-Tobu, 25, 0.666, 0.597, 0.7256, 0.7625, 0.7436, 0.5918, 0.7818, 0.9729
# Hokkaido Iburi-Tobu, 26, 0.663, 0.519, 0.6962, 0.7986, 0.7439, 0.5922, 0.7813, 0.9717
# Hokkaido Iburi-Tobu, 27, 0.656, 0.580, 0.5675, 0.8643, 0.6851, 0.5211, 0.7391, 0.9591
# Hokkaido Iburi-Tobu, 28, 0.684, 0.560, 0.6125, 0.8509, 0.7123, 0.5531, 0.7580, 0.9646
# Hokkaido Iburi-Tobu, 29, 0.659, 0.549, 0.6907, 0.7710, 0.7286, 0.5731, 0.7711, 0.9704
# Hokkaido Iburi-Tobu, 30, 0.622, 0.566, 0.6101, 0.8265, 0.7020, 0.5409, 0.7515, 0.9638
# Hokkaido Iburi-Tobu, 31, 0.656, 0.571, 0.7020, 0.7610, 0.7303, 0.5752, 0.7725, 0.9710
# Hokkaido Iburi-Tobu, 32, 0.683, 0.650, 0.7402, 0.6608, 0.6983, 0.5364, 0.7530, 0.9706
# Hokkaido Iburi-Tobu, 33, 0.629, 0.541, 0.7021, 0.7640, 0.7318, 0.5770, 0.7735, 0.9711
# Hokkaido Iburi-Tobu, 34, 0.645, 0.605, 0.5798, 0.8801, 0.6991, 0.5374, 0.7482, 0.9610
# Hokkaido Iburi-Tobu, 35, 0.593, 0.606, 0.6170, 0.8573, 0.7176, 0.5596, 0.7616, 0.9652
# Hokkaido Iburi-Tobu, 36, 0.610, 0.513, 0.6682, 0.8219, 0.7371, 0.5837, 0.7761, 0.9698
# Hokkaido Iburi-Tobu, 0.6940, 0.8203, 0.7519, 0.6024, 0.7760, 0.9531
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Jiuzhai valley (UAV-0.2m), 1, 1.899, 1.936, 0.0000, 0.0000, 0.0000, 0.0000, 0.3727, 0.7454
# Jiuzhai valley (UAV-0.2m), 2, 1.811, 1.874, 0.0000, 0.0000, 0.0000, 0.0000, 0.3727, 0.7454
# Jiuzhai valley (UAV-0.2m), 3, 1.731, 1.778, 0.9378, 0.3370, 0.4959, 0.3297, 0.5694, 0.8255
# Jiuzhai valley (UAV-0.2m), 4, 1.622, 1.610, 0.8817, 0.7293, 0.7983, 0.6643, 0.7745, 0.9062
# Jiuzhai valley (UAV-0.2m), 5, 1.511, 1.512, 0.5584, 0.9320, 0.6983, 0.5365, 0.6339, 0.7950
# Jiuzhai valley (UAV-0.2m), 6, 1.437, 1.425, 0.6474, 0.9099, 0.7565, 0.6084, 0.7071, 0.8509
# Jiuzhai valley (UAV-0.2m), 7, 1.356, 1.341, 0.7398, 0.8864, 0.8065, 0.6757, 0.7679, 0.8917
# Jiuzhai valley (UAV-0.2m), 8, 1.312, 1.315, 0.6999, 0.9130, 0.7924, 0.6561, 0.7487, 0.8782
# Jiuzhai valley (UAV-0.2m), 9, 1.279, 1.286, 0.7338, 0.9013, 0.8090, 0.6793, 0.7693, 0.8916
# Jiuzhai valley (UAV-0.2m), 10, 1.196, 1.169, 0.7733, 0.8986, 0.8312, 0.7112, 0.7954, 0.9071
# Jiuzhai valley (UAV-0.2m), 11, 1.153, 1.352, 0.7765, 0.5640, 0.6534, 0.4852, 0.6537, 0.8477
# Jiuzhai valley (UAV-0.2m), 12, 1.201, 1.252, 0.7547, 0.6551, 0.7014, 0.5401, 0.6848, 0.8580
# Jiuzhai valley (UAV-0.2m), 13, 1.031, 1.206, 0.6122, 0.7790, 0.6856, 0.5216, 0.6474, 0.8181
# Jiuzhai valley (UAV-0.2m), 14, 0.971, 0.777, 0.6530, 0.9685, 0.7801, 0.6394, 0.7274, 0.8609
# Jiuzhai valley (UAV-0.2m), 15, 1.008, 0.717, 0.6649, 0.9689, 0.7886, 0.6510, 0.7377, 0.8677
# Jiuzhai valley (UAV-0.2m), 16, 0.893, 1.332, 0.6168, 0.8583, 0.7178, 0.5598, 0.6699, 0.8281
# Jiuzhai valley (UAV-0.2m), 17, 0.942, 1.154, 0.5466, 0.9150, 0.6844, 0.5202, 0.6200, 0.7851
# Jiuzhai valley (UAV-0.2m), 18, 0.855, 0.956, 0.5284, 0.9888, 0.6887, 0.5252, 0.6106, 0.7724
# Jiuzhai valley (UAV-0.2m), 19, 0.806, 0.910, 0.5640, 0.9830, 0.7168, 0.5586, 0.6474, 0.8022
# Jiuzhai valley (UAV-0.2m), 20, 0.876, 0.801, 0.6259, 0.9741, 0.7621, 0.6156, 0.7048, 0.8451
# Jiuzhai valley (UAV-0.2m), 0.6915, 0.6139, 0.6504, 0.4819, 0.6506, 0.8453
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Jiuzhai valley (UAV-0.5m), 1, 1.762, 1.822, 0.0000, 0.0000, 0.0000, 0.0000, 0.4185, 0.8370
# Jiuzhai valley (UAV-0.5m), 2, 1.728, 1.795, 0.0000, 0.0000, 0.0000, 0.0000, 0.4185, 0.8370
# Jiuzhai valley (UAV-0.5m), 3, 1.679, 1.755, 0.0000, 0.0000, 0.0000, 0.0000, 0.4185, 0.8370
# Jiuzhai valley (UAV-0.5m), 4, 1.626, 1.684, 0.0000, 0.0000, 0.0000, 0.0000, 0.4185, 0.8370
# Jiuzhai valley (UAV-0.5m), 5, 1.529, 1.512, 0.7127, 0.1293, 0.2189, 0.1229, 0.4846, 0.8496
# Jiuzhai valley (UAV-0.5m), 6, 1.323, 1.329, 0.7978, 0.3171, 0.4538, 0.2935, 0.5812, 0.8756
# Jiuzhai valley (UAV-0.5m), 7, 1.153, 1.077, 0.8643, 0.6709, 0.7554, 0.6070, 0.7637, 0.9292
# Jiuzhai valley (UAV-0.5m), 8, 1.060, 4.174, 0.9324, 0.3518, 0.5109, 0.3431, 0.6133, 0.8902
# Jiuzhai valley (UAV-0.5m), 9, 0.954, 1.187, 0.9268, 0.6606, 0.7714, 0.6279, 0.7782, 0.9362
# Jiuzhai valley (UAV-0.5m), 10, 0.967, 2.393, 0.9135, 0.5254, 0.6671, 0.5005, 0.7035, 0.9145
# Jiuzhai valley (UAV-0.5m), 11, 0.864, 1.516, 0.8474, 0.6268, 0.7206, 0.5632, 0.7375, 0.9208
# Jiuzhai valley (UAV-0.5m), 12, 0.892, 0.641, 0.7649, 0.9310, 0.8398, 0.7239, 0.8278, 0.9421
# Jiuzhai valley (UAV-0.5m), 13, 0.895, 0.876, 0.7544, 0.8615, 0.8044, 0.6728, 0.7967, 0.9317
# Jiuzhai valley (UAV-0.5m), 14, 0.932, 0.621, 0.7845, 0.8664, 0.8235, 0.6999, 0.8147, 0.9395
# Jiuzhai valley (UAV-0.5m), 15, 0.859, 0.779, 0.8383, 0.7680, 0.8016, 0.6689, 0.7991, 0.9381
# Jiuzhai valley (UAV-0.5m), 16, 0.827, 0.660, 0.8401, 0.7949, 0.8169, 0.6905, 0.8119, 0.9419
# Jiuzhai valley (UAV-0.5m), 17, 0.848, 0.759, 0.8522, 0.7783, 0.8136, 0.6857, 0.8096, 0.9419
# Jiuzhai valley (UAV-0.5m), 18, 0.736, 0.671, 0.8437, 0.8050, 0.8239, 0.7006, 0.8180, 0.9439
# Jiuzhai valley (UAV-0.5m), 19, 0.805, 0.527, 0.7951, 0.9064, 0.8471, 0.7348, 0.8361, 0.9467
# Jiuzhai valley (UAV-0.5m), 20, 0.739, 1.037, 0.7200, 0.8049, 0.7601, 0.6130, 0.7589, 0.9172
# Jiuzhai valley (UAV-0.5m), 21, 0.716, 0.516, 0.7948, 0.9077, 0.8475, 0.7354, 0.8365, 0.9468
# Jiuzhai valley (UAV-0.5m), 22, 0.688, 0.482, 0.8101, 0.9227, 0.8627, 0.7586, 0.8512, 0.9522
# Jiuzhai valley (UAV-0.5m), 23, 0.689, 1.509, 0.8239, 0.6755, 0.7424, 0.5903, 0.7522, 0.9236
# Jiuzhai valley (UAV-0.5m), 24, 0.829, 0.597, 0.8717, 0.7868, 0.8270, 0.7051, 0.8218, 0.9464
# Jiuzhai valley (UAV-0.5m), 25, 0.740, 0.479, 0.8149, 0.9068, 0.8584, 0.7519, 0.8473, 0.9512
# Jiuzhai valley (UAV-0.5m), 26, 0.701, 0.564, 0.7779, 0.8570, 0.8155, 0.6885, 0.8076, 0.9368
# Jiuzhai valley (UAV-0.5m), 27, 0.691, 0.654, 0.7770, 0.8422, 0.8083, 0.6783, 0.8014, 0.9349
# Jiuzhai valley (UAV-0.5m), 28, 0.729, 0.867, 0.7212, 0.8211, 0.7679, 0.6233, 0.7649, 0.9191
# Jiuzhai valley (UAV-0.5m), 29, 0.681, 0.632, 0.6609, 0.9274, 0.7718, 0.6284, 0.7615, 0.9106
# Jiuzhai valley (UAV-0.5m), 30, 0.609, 0.868, 0.5891, 0.8023, 0.6794, 0.5144, 0.6862, 0.8766
# Jiuzhai valley (UAV-0.5m), 31, 0.646, 0.789, 0.6875, 0.7818, 0.7317, 0.5769, 0.7349, 0.9065
# Jiuzhai valley (UAV-0.5m), 32, 0.595, 0.432, 0.7904, 0.9235, 0.8518, 0.7418, 0.8401, 0.9476
# Jiuzhai valley (UAV-0.5m), 0.5523, 0.7916, 0.6506, 0.4822, 0.6981, 0.9204
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Lombok, 1, 1.764, 1.763, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 2, 1.730, 1.745, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 3, 1.690, 1.704, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 4, 1.624, 1.589, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 5, 1.476, 1.239, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 6, 1.388, 1.597, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 7, 1.307, 1.303, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 8, 1.284, 1.245, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 9, 1.249, 1.236, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 10, 1.227, 1.213, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 11, 1.224, 1.198, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 12, 1.185, 1.187, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 13, 1.164, 1.170, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 14, 1.137, 1.150, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 15, 1.117, 1.151, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 16, 1.159, 1.135, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 17, 1.139, 1.122, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 18, 1.090, 1.178, 0.0000, 0.0000, 0.0000, 0.0000, 0.4923, 0.9846
# Lombok, 19, 1.078, 1.135, 0.0730, 0.0002, 0.0003, 0.0002, 0.4923, 0.9845
# Lombok, 20, 1.049, 1.088, 0.0366, 0.0009, 0.0018, 0.0009, 0.4925, 0.9842
# Lombok, 21, 1.093, 1.132, 0.0874, 0.0106, 0.0189, 0.0095, 0.4963, 0.9830
# Lombok, 22, 1.010, 1.114, 0.7385, 0.0069, 0.0136, 0.0069, 0.4957, 0.9846
# Lombok, 23, 1.023, 1.081, 0.3180, 0.0329, 0.0596, 0.0307, 0.5073, 0.9840
# Lombok, 24, 1.021, 1.075, 0.2856, 0.0382, 0.0673, 0.0348, 0.5093, 0.9837
# Lombok, 25, 1.030, 1.065, 0.4446, 0.0490, 0.0882, 0.0462, 0.5153, 0.9844
# Lombok, 26, 0.939, 1.139, 0.0603, 0.1447, 0.0852, 0.0445, 0.4982, 0.9520
# Lombok, 27, 0.989, 1.070, 0.2491, 0.1224, 0.1642, 0.0894, 0.5351, 0.9807
# Lombok, 28, 1.087, 1.101, 0.1169, 0.0849, 0.0984, 0.0517, 0.5138, 0.9760
# Lombok, 29, 0.959, 1.079, 0.6488, 0.0849, 0.1502, 0.0812, 0.5332, 0.9852
# Lombok, 30, 0.971, 1.166, 0.7566, 0.0575, 0.1069, 0.0565, 0.5208, 0.9852
# Lombok, 31, 0.902, 1.119, 0.6649, 0.0699, 0.1265, 0.0675, 0.5263, 0.9851
# Lombok, 32, 0.944, 1.026, 0.3765, 0.1548, 0.2194, 0.1232, 0.5531, 0.9830
# Lombok, 33, 0.831, 1.003, 0.3589, 0.2327, 0.2824, 0.1644, 0.5730, 0.9817
# Lombok, 34, 0.927, 1.005, 0.2903, 0.2286, 0.2558, 0.1467, 0.5630, 0.9794
# Lombok, 35, 0.834, 1.008, 0.3172, 0.2239, 0.2625, 0.1511, 0.5658, 0.9806
# Lombok, 36, 0.811, 1.088, 0.2658, 0.1906, 0.2220, 0.1249, 0.5521, 0.9794
# Lombok, 37, 0.853, 1.032, 0.3533, 0.1999, 0.2553, 0.1464, 0.5641, 0.9820
# Lombok, 38, 0.736, 1.011, 0.3296, 0.2618, 0.2918, 0.1708, 0.5756, 0.9804
# Lombok, 39, 0.763, 0.969, 0.3335, 0.2745, 0.3011, 0.1773, 0.5787, 0.9803
# Lombok, 40, 0.765, 0.955, 0.3318, 0.3003, 0.3153, 0.1871, 0.5834, 0.9798
# Lombok, 0.3321, 0.5099, 0.4022, 0.2517, 0.6086, 0.9658
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Longxi River (SAT), 1, 1.751, 1.706, 0.0000, 0.0000, 0.0000, 0.0000, 0.4620, 0.9240
# Longxi River (SAT), 2, 1.708, 1.700, 0.0000, 0.0000, 0.0000, 0.0000, 0.4620, 0.9240
# Longxi River (SAT), 3, 1.670, 1.690, 0.0000, 0.0000, 0.0000, 0.0000, 0.4620, 0.9240
# Longxi River (SAT), 4, 1.620, 1.668, 0.0000, 0.0000, 0.0000, 0.0000, 0.4620, 0.9240
# Longxi River (SAT), 5, 1.519, 1.594, 0.0000, 0.0000, 0.0000, 0.0000, 0.4620, 0.9240
# Longxi River (SAT), 6, 1.264, 3.517, 0.0000, 0.0000, 0.0000, 0.0000, 0.4620, 0.9240
# Longxi River (SAT), 7, 0.956, 2.764, 1.0000, 0.0035, 0.0070, 0.0035, 0.4639, 0.9243
# Longxi River (SAT), 8, 0.838, 1.609, 0.9558, 0.1580, 0.2712, 0.1569, 0.5458, 0.9355
# Longxi River (SAT), 9, 0.707, 1.108, 0.8846, 0.3699, 0.5216, 0.3528, 0.6499, 0.9485
# Longxi River (SAT), 10, 0.719, 1.255, 0.8020, 0.4538, 0.5796, 0.4081, 0.6781, 0.9500
# Longxi River (SAT), 11, 0.659, 0.702, 0.5885, 0.8212, 0.6856, 0.5216, 0.7303, 0.9428
# Longxi River (SAT), 12, 0.652, 0.732, 0.6425, 0.7261, 0.6818, 0.5172, 0.7313, 0.9485
# Longxi River (SAT), 13, 0.630, 0.765, 0.6767, 0.6756, 0.6762, 0.5108, 0.7295, 0.9508
# Longxi River (SAT), 14, 0.703, 0.701, 0.5471, 0.8978, 0.6799, 0.5150, 0.7230, 0.9358
# Longxi River (SAT), 15, 0.651, 0.637, 0.6247, 0.8361, 0.7151, 0.5565, 0.7512, 0.9494
# Longxi River (SAT), 16, 0.656, 0.766, 0.7054, 0.6546, 0.6791, 0.5141, 0.7323, 0.9530
# Longxi River (SAT), 17, 0.598, 0.670, 0.6669, 0.7367, 0.7000, 0.5385, 0.7438, 0.9520
# Longxi River (SAT), 18, 0.702, 0.669, 0.5619, 0.8861, 0.6877, 0.5240, 0.7292, 0.9388
# Longxi River (SAT), 19, 0.613, 0.605, 0.6600, 0.7734, 0.7122, 0.5531, 0.7513, 0.9525
# Longxi River (SAT), 20, 0.621, 0.653, 0.6711, 0.7249, 0.6970, 0.5349, 0.7421, 0.9521
# Longxi River (SAT), 21, 0.561, 0.607, 0.6650, 0.7953, 0.7243, 0.5678, 0.7594, 0.9540
# Longxi River (SAT), 22, 0.656, 0.663, 0.6280, 0.7734, 0.6932, 0.5304, 0.7376, 0.9480
# Longxi River (SAT), 23, 0.651, 0.656, 0.5804, 0.8240, 0.6811, 0.5164, 0.7269, 0.9414
# Longxi River (SAT), 24, 0.629, 0.663, 0.5246, 0.8984, 0.6624, 0.4952, 0.7103, 0.9304
# Longxi River (SAT), 25, 0.755, 0.604, 0.5979, 0.8556, 0.7039, 0.5431, 0.7423, 0.9453
# Longxi River (SAT), 26, 0.621, 0.719, 0.6561, 0.7128, 0.6832, 0.5189, 0.7329, 0.9498
# Longxi River (SAT), 27, 0.731, 0.684, 0.5922, 0.8321, 0.6920, 0.5290, 0.7345, 0.9437
# Longxi River (SAT), 28, 0.720, 1.045, 0.3780, 0.9566, 0.5419, 0.3717, 0.6196, 0.8771
# Longxi River (SAT), 29, 0.671, 0.690, 0.5631, 0.8763, 0.6856, 0.5217, 0.7281, 0.9390
# Longxi River (SAT), 30, 0.601, 0.671, 0.6793, 0.7207, 0.6994, 0.5377, 0.7440, 0.9529
# Longxi River (SAT), 31, 0.650, 0.641, 0.6779, 0.7341, 0.7049, 0.5443, 0.7474, 0.9533
# Longxi River (SAT), 0.6038, 0.7645, 0.6747, 0.5091, 0.7298, 0.9529
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Longxi River (UAV), 1, 1.817, 1.843, 0.0000, 0.0000, 0.0000, 0.0000, 0.4151, 0.8301
# Longxi River (UAV), 2, 1.775, 1.827, 0.0000, 0.0000, 0.0000, 0.0000, 0.4151, 0.8301
# Longxi River (UAV), 3, 1.725, 1.796, 0.0000, 0.0000, 0.0000, 0.0000, 0.4151, 0.8301
# Longxi River (UAV), 4, 1.663, 1.734, 0.4558, 0.1064, 0.1725, 0.0944, 0.4589, 0.8266
# Longxi River (UAV), 5, 1.570, 1.607, 0.5510, 0.7034, 0.6180, 0.4471, 0.6397, 0.8522
# Longxi River (UAV), 6, 1.504, 1.549, 0.5826, 0.6977, 0.6350, 0.4652, 0.6553, 0.8637
# Longxi River (UAV), 7, 1.474, 1.485, 0.5773, 0.7402, 0.6487, 0.4801, 0.6621, 0.8638
# Longxi River (UAV), 8, 1.405, 1.386, 0.5133, 0.8897, 0.6510, 0.4826, 0.6458, 0.8379
# Longxi River (UAV), 9, 1.350, 1.290, 0.5366, 0.8537, 0.6590, 0.4914, 0.6579, 0.8499
# Longxi River (UAV), 10, 1.318, 1.238, 0.5221, 0.8797, 0.6553, 0.4873, 0.6512, 0.8427
# Longxi River (UAV), 11, 1.237, 1.183, 0.5439, 0.8357, 0.6589, 0.4914, 0.6600, 0.8530
# Longxi River (UAV), 12, 1.210, 1.161, 0.5676, 0.7559, 0.6483, 0.4797, 0.6599, 0.8607
# Longxi River (UAV), 13, 1.233, 1.099, 0.5497, 0.7973, 0.6507, 0.4823, 0.6570, 0.8546
# Longxi River (UAV), 14, 1.188, 1.097, 0.5134, 0.8588, 0.6426, 0.4734, 0.6417, 0.8377
# Longxi River (UAV), 15, 1.145, 1.062, 0.5249, 0.8552, 0.6506, 0.4821, 0.6497, 0.8439
# Longxi River (UAV), 16, 1.137, 1.061, 0.5646, 0.7742, 0.6530, 0.4847, 0.6619, 0.8602
# Longxi River (UAV), 17, 1.168, 1.040, 0.5523, 0.8146, 0.6583, 0.4906, 0.6620, 0.8563
# Longxi River (UAV), 18, 1.019, 1.039, 0.5094, 0.8799, 0.6452, 0.4763, 0.6415, 0.8356
# Longxi River (UAV), 19, 1.023, 1.013, 0.5348, 0.8612, 0.6598, 0.4923, 0.6578, 0.8491
# Longxi River (UAV), 20, 0.999, 1.024, 0.5490, 0.8208, 0.6580, 0.4903, 0.6609, 0.8550
# Longxi River (UAV), 21, 1.021, 1.004, 0.4919, 0.8941, 0.6346, 0.4648, 0.6293, 0.8251
# Longxi River (UAV), 22, 0.988, 1.006, 0.4839, 0.9073, 0.6312, 0.4611, 0.6240, 0.8198
# Longxi River (UAV), 23, 0.868, 1.125, 0.6193, 0.6667, 0.6422, 0.4729, 0.6653, 0.8738
# Longxi River (UAV), 24, 1.045, 1.024, 0.5424, 0.8374, 0.6583, 0.4907, 0.6593, 0.8523
# Longxi River (UAV), 25, 0.920, 0.994, 0.5515, 0.8310, 0.6630, 0.4959, 0.6644, 0.8565
# Longxi River (UAV), 26, 0.951, 1.168, 0.4325, 0.9249, 0.5894, 0.4179, 0.5791, 0.7811
# Longxi River (UAV), 27, 0.836, 1.262, 0.4099, 0.9481, 0.5724, 0.4009, 0.5570, 0.7593
# Longxi River (UAV), 28, 0.826, 1.002, 0.4877, 0.9019, 0.6331, 0.4632, 0.6267, 0.8224
# Longxi River (UAV), 29, 0.806, 1.094, 0.5912, 0.7133, 0.6466, 0.4777, 0.6635, 0.8675
# Longxi River (UAV), 30, 0.861, 1.061, 0.5870, 0.7419, 0.6554, 0.4875, 0.6679, 0.8675
# Longxi River (UAV), 31, 0.772, 0.986, 0.4909, 0.9185, 0.6398, 0.4704, 0.6311, 0.8243
# Longxi River (UAV), 32, 0.813, 1.244, 0.4292, 0.9641, 0.5939, 0.4224, 0.5773, 0.7760
# Longxi River (UAV), 33, 0.773, 1.256, 0.4272, 0.9499, 0.5894, 0.4178, 0.5748, 0.7751
# Longxi River (UAV), 34, 0.720, 1.036, 0.5950, 0.7462, 0.6621, 0.4949, 0.6733, 0.8706
# Longxi River (UAV), 35, 0.657, 1.154, 0.6492, 0.6398, 0.6444, 0.4754, 0.6704, 0.8801
# Longxi River (UAV), 0.5914, 0.8088, 0.6833, 0.5189, 0.6890, 0.8777
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Mengdong Township, 1, 1.725, 1.692, 0.0000, 0.0000, 0.0000, 0.0000, 0.4678, 0.9355
# Mengdong Township, 2, 1.677, 1.683, 0.0000, 0.0000, 0.0000, 0.0000, 0.4678, 0.9355
# Mengdong Township, 3, 1.628, 1.668, 0.0000, 0.0000, 0.0000, 0.0000, 0.4678, 0.9355
# Mengdong Township, 4, 1.592, 1.643, 0.3259, 0.2574, 0.2876, 0.1680, 0.5422, 0.9178
# Mengdong Township, 5, 1.544, 1.586, 0.3114, 0.3289, 0.3199, 0.1904, 0.5491, 0.9098
# Mengdong Township, 6, 1.446, 1.652, 0.7732, 0.0129, 0.0253, 0.0128, 0.4744, 0.9361
# Mengdong Township, 7, 1.211, 4.445, 0.8878, 0.0071, 0.0141, 0.0071, 0.4715, 0.9359
# Mengdong Township, 8, 1.093, 2.116, 0.7567, 0.0739, 0.1347, 0.0722, 0.5053, 0.9387
# Mengdong Township, 9, 1.105, 1.885, 0.6647, 0.1262, 0.2121, 0.1186, 0.5288, 0.9395
# Mengdong Township, 10, 0.941, 1.012, 0.4093, 0.5712, 0.4769, 0.3131, 0.6146, 0.9192
# Mengdong Township, 11, 0.921, 0.989, 0.4246, 0.5692, 0.4864, 0.3213, 0.6204, 0.9225
# Mengdong Township, 12, 0.915, 0.927, 0.4415, 0.6073, 0.5113, 0.3435, 0.6328, 0.9251
# Mengdong Township, 13, 0.866, 0.916, 0.4052, 0.6862, 0.5095, 0.3418, 0.6263, 0.9148
# Mengdong Township, 14, 0.821, 0.827, 0.5476, 0.6025, 0.5737, 0.4023, 0.6711, 0.9423
# Mengdong Township, 15, 0.846, 0.886, 0.4092, 0.7192, 0.5216, 0.3528, 0.6318, 0.9149
# Mengdong Township, 16, 0.851, 0.811, 0.4908, 0.6920, 0.5743, 0.4028, 0.6668, 0.9338
# Mengdong Township, 17, 0.770, 0.789, 0.5341, 0.6841, 0.5999, 0.4285, 0.6834, 0.9411
# Mengdong Township, 18, 0.753, 0.818, 0.4610, 0.7424, 0.5688, 0.3975, 0.6606, 0.9274
# Mengdong Township, 19, 0.739, 0.753, 0.5548, 0.7007, 0.6193, 0.4485, 0.6952, 0.9444
# Mengdong Township, 20, 0.768, 0.826, 0.4376, 0.7573, 0.5547, 0.3838, 0.6507, 0.9216
# Mengdong Township, 21, 0.778, 0.770, 0.5204, 0.7197, 0.6040, 0.4327, 0.6844, 0.9391
# Mengdong Township, 22, 0.715, 0.802, 0.6050, 0.6471, 0.6253, 0.4549, 0.7014, 0.9500
# Mengdong Township, 23, 0.698, 0.747, 0.5655, 0.7168, 0.6322, 0.4622, 0.7029, 0.9462
# Mengdong Township, 24, 0.671, 0.784, 0.5541, 0.6915, 0.6152, 0.4443, 0.6929, 0.9442
# Mengdong Township, 25, 0.705, 0.795, 0.5406, 0.6917, 0.6069, 0.4356, 0.6876, 0.9422
# Mengdong Township, 26, 0.676, 0.772, 0.4989, 0.7768, 0.6075, 0.4363, 0.6841, 0.9353
# Mengdong Township, 27, 0.648, 0.800, 0.4613, 0.8101, 0.5879, 0.4163, 0.6695, 0.9267
# Mengdong Township, 28, 0.634, 0.783, 0.4923, 0.7646, 0.5989, 0.4275, 0.6790, 0.9340
# Mengdong Township, 29, 0.648, 0.765, 0.5419, 0.7385, 0.6251, 0.4547, 0.6973, 0.9429
# Mengdong Township, 30, 0.564, 0.752, 0.5941, 0.6739, 0.6315, 0.4615, 0.7042, 0.9493
# Mengdong Township, 31, 0.561, 0.768, 0.4602, 0.8604, 0.5996, 0.4282, 0.6749, 0.9259
# Mengdong Township, 32, 0.625, 0.861, 0.5434, 0.6458, 0.5902, 0.4186, 0.6791, 0.9422
# Mengdong Township, 33, 0.864, 1.499, 0.4349, 0.3221, 0.3701, 0.2270, 0.5774, 0.9293
# Mengdong Township, 0.6062, 0.8132, 0.6946, 0.5321, 0.7123, 0.9042
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Moxi town (UAV-0.2m), 1, 1.780, 1.872, 0.0000, 0.0000, 0.0000, 0.0000, 0.4091, 0.8183
# Moxi town (UAV-0.2m), 2, 1.764, 1.864, 0.0000, 0.0000, 0.0000, 0.0000, 0.4091, 0.8183
# Moxi town (UAV-0.2m), 3, 1.753, 1.848, 0.0000, 0.0000, 0.0000, 0.0000, 0.4091, 0.8183
# Moxi town (UAV-0.2m), 4, 1.734, 1.820, 0.0000, 0.0000, 0.0000, 0.0000, 0.4091, 0.8183
# Moxi town (UAV-0.2m), 5, 1.708, 1.768, 1.0000, 0.0002, 0.0003, 0.0002, 0.4092, 0.8183
# Moxi town (UAV-0.2m), 6, 1.670, 1.618, 0.5958, 0.5189, 0.5547, 0.3838, 0.6083, 0.8486
# Moxi town (UAV-0.2m), 7, 1.581, 1.728, 0.3737, 0.8743, 0.5236, 0.3546, 0.5054, 0.7108
# Moxi town (UAV-0.2m), 8, 1.535, 1.302, 0.5998, 0.7440, 0.6641, 0.4971, 0.6695, 0.8632
# Moxi town (UAV-0.2m), 9, 1.419, 1.200, 0.6157, 0.7421, 0.6730, 0.5072, 0.6779, 0.8690
# Moxi town (UAV-0.2m), 10, 1.276, 1.273, 0.5185, 0.7250, 0.6046, 0.4333, 0.6174, 0.8277
# Moxi town (UAV-0.2m), 11, 1.223, 1.103, 0.7213, 0.6440, 0.6804, 0.5156, 0.6956, 0.8901
# Moxi town (UAV-0.2m), 12, 1.169, 1.080, 0.5928, 0.7595, 0.6659, 0.4991, 0.6692, 0.8615
# Moxi town (UAV-0.2m), 13, 1.086, 1.223, 0.5346, 0.7174, 0.6127, 0.4416, 0.6260, 0.8352
# Moxi town (UAV-0.2m), 14, 1.119, 1.042, 0.6757, 0.7056, 0.6903, 0.5271, 0.6976, 0.8850
# Moxi town (UAV-0.2m), 15, 1.021, 0.980, 0.6272, 0.7762, 0.6938, 0.5312, 0.6931, 0.8755
# Moxi town (UAV-0.2m), 16, 1.059, 1.101, 0.6735, 0.7065, 0.6896, 0.5263, 0.6968, 0.8844
# Moxi town (UAV-0.2m), 17, 0.962, 1.055, 0.7270, 0.6813, 0.7034, 0.5425, 0.7117, 0.8956
# Moxi town (UAV-0.2m), 18, 1.004, 0.917, 0.6087, 0.8268, 0.7012, 0.5399, 0.6946, 0.8719
# Moxi town (UAV-0.2m), 19, 0.884, 1.039, 0.6964, 0.7171, 0.7066, 0.5463, 0.7109, 0.8918
# Moxi town (UAV-0.2m), 20, 0.987, 1.120, 0.6606, 0.7149, 0.6867, 0.5228, 0.6933, 0.8814
# Moxi town (UAV-0.2m), 21, 0.961, 0.981, 0.6105, 0.7851, 0.6869, 0.5231, 0.6857, 0.8699
# Moxi town (UAV-0.2m), 22, 0.945, 1.002, 0.5310, 0.8548, 0.6551, 0.4871, 0.6467, 0.8364
# Moxi town (UAV-0.2m), 23, 0.760, 1.061, 0.4916, 0.9017, 0.6363, 0.4666, 0.6213, 0.8127
# Moxi town (UAV-0.2m), 24, 0.779, 1.017, 0.6049, 0.7942, 0.6867, 0.5229, 0.6845, 0.8683
# Moxi town (UAV-0.2m), 25, 0.714, 1.018, 0.6655, 0.7799, 0.7182, 0.5602, 0.7153, 0.8887
# Moxi town (UAV-0.2m), 26, 0.637, 1.007, 0.5419, 0.8969, 0.6756, 0.5101, 0.6616, 0.8435
# Moxi town (UAV-0.2m), 27, 0.708, 0.999, 0.6793, 0.7921, 0.7314, 0.5765, 0.7265, 0.8943
# Moxi town (UAV-0.2m), 28, 0.904, 0.954, 0.5543, 0.8831, 0.6811, 0.5164, 0.6687, 0.8497
# Moxi town (UAV-0.2m), 29, 0.616, 0.996, 0.6499, 0.8005, 0.7174, 0.5593, 0.7126, 0.8854
# Moxi town (UAV-0.2m), 30, 0.559, 0.926, 0.6632, 0.8389, 0.7408, 0.5883, 0.7312, 0.8933
# Moxi town (UAV-0.2m), 31, 0.471, 1.014, 0.6539, 0.8511, 0.7396, 0.5868, 0.7290, 0.8911
# Moxi town (UAV-0.2m), 32, 0.466, 2.045, 0.8397, 0.4951, 0.6229, 0.4523, 0.6663, 0.8911
# Moxi town (UAV-0.2m), 33, 0.425, 1.099, 0.5943, 0.8925, 0.7135, 0.5547, 0.6996, 0.8698
# Moxi town (UAV-0.2m), 34, 0.393, 1.442, 0.8480, 0.6611, 0.7430, 0.5911, 0.7483, 0.9169
# Moxi town (UAV-0.2m), 35, 0.376, 1.073, 0.6445, 0.8295, 0.7254, 0.5691, 0.7174, 0.8859
# Moxi town (UAV-0.2m), 36, 0.575, 0.987, 0.6320, 0.8787, 0.7352, 0.5813, 0.7222, 0.8850
# Moxi town (UAV-0.2m), 37, 0.455, 2.002, 0.7736, 0.5321, 0.6305, 0.4604, 0.6675, 0.8867
# Moxi town (UAV-0.2m), 38, 0.439, 1.539, 0.7487, 0.6723, 0.7084, 0.5485, 0.7170, 0.8994
# Moxi town (UAV-0.2m), 39, 0.380, 1.334, 0.5711, 0.8113, 0.6704, 0.5042, 0.6670, 0.8550
# Moxi town (UAV-0.2m), 40, 0.307, 2.506, 0.7096, 0.4625, 0.5600, 0.3889, 0.6223, 0.8679
# Moxi town (UAV-0.2m), 0.8909, 0.6006, 0.7175, 0.5595, 0.6959, 0.8617
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Moxi town (UAV-1m), 1, 1.737, 1.764, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 2, 1.704, 1.748, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 3, 1.664, 1.719, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 4, 1.603, 1.651, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 5, 1.506, 1.526, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 6, 1.420, 1.892, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 7, 1.352, 1.479, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 8, 1.318, 2.228, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 9, 1.235, 1.921, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 10, 1.240, 1.808, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 11, 1.177, 2.354, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 12, 1.186, 1.415, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 13, 1.156, 1.244, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 14, 1.155, 1.173, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 15, 1.093, 1.200, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 16, 1.058, 2.152, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 17, 1.086, 1.135, 0.0000, 0.0000, 0.0000, 0.0000, 0.4546, 0.9091
# Moxi town (UAV-1m), 18, 1.070, 1.079, 0.4560, 0.1290, 0.2011, 0.1118, 0.5088, 0.9068
# Moxi town (UAV-1m), 19, 1.063, 1.021, 0.4241, 0.3644, 0.3920, 0.2438, 0.5687, 0.8972
# Moxi town (UAV-1m), 20, 1.027, 1.012, 0.5076, 0.4411, 0.4720, 0.3089, 0.6077, 0.9103
# Moxi town (UAV-1m), 21, 1.070, 1.023, 0.4278, 0.5892, 0.4957, 0.3295, 0.6072, 0.8910
# Moxi town (UAV-1m), 22, 1.026, 1.168, 0.3788, 0.6876, 0.4885, 0.3232, 0.5918, 0.8691
# Moxi town (UAV-1m), 23, 1.000, 1.463, 0.5355, 0.4252, 0.4740, 0.3106, 0.6107, 0.9142
# Moxi town (UAV-1m), 24, 0.876, 0.939, 0.4094, 0.8776, 0.5584, 0.3873, 0.6251, 0.8738
# Moxi town (UAV-1m), 25, 0.838, 0.991, 0.4612, 0.7077, 0.5585, 0.3874, 0.6394, 0.8983
# Moxi town (UAV-1m), 26, 0.833, 0.889, 0.4223, 0.8791, 0.5705, 0.3991, 0.6342, 0.8797
# Moxi town (UAV-1m), 27, 0.828, 0.748, 0.6401, 0.7387, 0.6859, 0.5219, 0.7280, 0.9385
# Moxi town (UAV-1m), 28, 0.758, 1.215, 0.4797, 0.5517, 0.5132, 0.3452, 0.6225, 0.9049
# Moxi town (UAV-1m), 29, 0.704, 0.859, 0.4636, 0.8539, 0.6010, 0.4296, 0.6589, 0.8969
# Moxi town (UAV-1m), 30, 0.710, 0.679, 0.5833, 0.8509, 0.6921, 0.5292, 0.7273, 0.9312
# Moxi town (UAV-1m), 31, 0.632, 0.662, 0.6188, 0.8231, 0.7065, 0.5462, 0.7395, 0.9378
# Moxi town (UAV-1m), 32, 0.621, 0.738, 0.6173, 0.7731, 0.6864, 0.5226, 0.7268, 0.9358
# Moxi town (UAV-1m), 33, 0.590, 0.686, 0.6368, 0.8031, 0.7103, 0.5508, 0.7433, 0.9405
# Moxi town (UAV-1m), 34, 0.566, 0.669, 0.8356, 0.6911, 0.7565, 0.6084, 0.7826, 0.9596
# Moxi town (UAV-1m), 35, 0.532, 0.722, 0.7678, 0.6899, 0.7268, 0.5708, 0.7603, 0.9529
# Moxi town (UAV-1m), 36, 0.544, 0.572, 0.7236, 0.8085, 0.7637, 0.6177, 0.7843, 0.9545
# Moxi town (UAV-1m), 37, 0.575, 0.559, 0.7025, 0.8360, 0.7635, 0.6174, 0.7832, 0.9529
# Moxi town (UAV-1m), 38, 0.523, 1.019, 0.4443, 0.8857, 0.5918, 0.4202, 0.6497, 0.8889
# Moxi town (UAV-1m), 39, 0.887, 0.953, 0.5226, 0.7553, 0.6177, 0.4469, 0.6778, 0.9150
# Moxi town (UAV-1m), 40, 0.635, 1.229, 0.7373, 0.4857, 0.5856, 0.4140, 0.6743, 0.9375
# Moxi town (UAV-1m), 0.6861, 0.7732, 0.7271, 0.5712, 0.7670, 0.9646
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Moxitaidi (SAT), 1, 1.740, 1.721, 0.0000, 0.0000, 0.0000, 0.0000, 0.4812, 0.9624
# Moxitaidi (SAT), 2, 1.708, 1.706, 0.0000, 0.0000, 0.0000, 0.0000, 0.4812, 0.9624
# Moxitaidi (SAT), 3, 1.659, 1.670, 0.0000, 0.0000, 0.0000, 0.0000, 0.4812, 0.9624
# Moxitaidi (SAT), 4, 1.582, 1.567, 0.0000, 0.0000, 0.0000, 0.0000, 0.4812, 0.9624
# Moxitaidi (SAT), 5, 1.445, 1.287, 0.0000, 0.0000, 0.0000, 0.0000, 0.4812, 0.9624
# Moxitaidi (SAT), 6, 1.292, 1.698, 0.0000, 0.0000, 0.0000, 0.0000, 0.4812, 0.9624
# Moxitaidi (SAT), 7, 1.227, 1.186, 0.0000, 0.0000, 0.0000, 0.0000, 0.4812, 0.9624
# Moxitaidi (SAT), 8, 1.190, 1.154, 0.0000, 0.0000, 0.0000, 0.0000, 0.4812, 0.9624
# Moxitaidi (SAT), 9, 1.145, 1.120, 0.9789, 0.0063, 0.0125, 0.0063, 0.4844, 0.9626
# Moxitaidi (SAT), 10, 1.071, 0.953, 0.9094, 0.2596, 0.4039, 0.2530, 0.6120, 0.9712
# Moxitaidi (SAT), 11, 1.056, 1.050, 0.2311, 0.5248, 0.3209, 0.1911, 0.5529, 0.9164
# Moxitaidi (SAT), 12, 1.094, 1.021, 0.2599, 0.5868, 0.3603, 0.2197, 0.5698, 0.9216
# Moxitaidi (SAT), 13, 1.021, 1.006, 0.7494, 0.3740, 0.4990, 0.3324, 0.6519, 0.9717
# Moxitaidi (SAT), 14, 0.946, 0.864, 0.5847, 0.5660, 0.5752, 0.4037, 0.6858, 0.9685
# Moxitaidi (SAT), 15, 0.932, 0.912, 0.4084, 0.6882, 0.5126, 0.3447, 0.6471, 0.9508
# Moxitaidi (SAT), 16, 0.965, 1.072, 0.2025, 0.7540, 0.3193, 0.1900, 0.5327, 0.8790
# Moxitaidi (SAT), 17, 1.071, 0.973, 0.2730, 0.6762, 0.3889, 0.2414, 0.5797, 0.9200
# Moxitaidi (SAT), 18, 0.909, 1.144, 0.6186, 0.3830, 0.4731, 0.3099, 0.6386, 0.9679
# Moxitaidi (SAT), 19, 0.882, 0.837, 0.4426, 0.7130, 0.5462, 0.3757, 0.6649, 0.9554
# Moxitaidi (SAT), 20, 0.842, 0.771, 0.5973, 0.5920, 0.5946, 0.4231, 0.6960, 0.9696
# Moxitaidi (SAT), 21, 0.727, 0.743, 0.5484, 0.6864, 0.6097, 0.4385, 0.7023, 0.9669
# Moxitaidi (SAT), 22, 0.744, 0.698, 0.5537, 0.6836, 0.6118, 0.4407, 0.7036, 0.9674
# Moxitaidi (SAT), 23, 0.629, 0.702, 0.5688, 0.6578, 0.6101, 0.4389, 0.7032, 0.9684
# Moxitaidi (SAT), 24, 0.823, 1.034, 0.2298, 0.8287, 0.3598, 0.2194, 0.5524, 0.8890
# Moxitaidi (SAT), 25, 0.756, 0.780, 0.5456, 0.5772, 0.5610, 0.3898, 0.6775, 0.9660
# Moxitaidi (SAT), 26, 0.686, 0.748, 0.4947, 0.6768, 0.5716, 0.4001, 0.6805, 0.9618
# Moxitaidi (SAT), 27, 0.596, 0.736, 0.4685, 0.7425, 0.5745, 0.4030, 0.6802, 0.9586
# Moxitaidi (SAT), 28, 0.560, 0.702, 0.6030, 0.5902, 0.5965, 0.4250, 0.6972, 0.9700
# Moxitaidi (SAT), 29, 0.503, 0.635, 0.6637, 0.6340, 0.6485, 0.4799, 0.7267, 0.9741
# Moxitaidi (SAT), 30, 0.488, 0.574, 0.6861, 0.6757, 0.6808, 0.5161, 0.7458, 0.9762
# Moxitaidi (SAT), 31, 0.498, 0.568, 0.6976, 0.6740, 0.6856, 0.5216, 0.7489, 0.9767
# Moxitaidi (SAT), 32, 0.412, 0.601, 0.5554, 0.7674, 0.6444, 0.4754, 0.7213, 0.9681
# Moxitaidi (SAT), 33, 0.498, 0.562, 0.6344, 0.7218, 0.6753, 0.5097, 0.7414, 0.9739
# Moxitaidi (SAT), 34, 0.485, 0.590, 0.6667, 0.6755, 0.6711, 0.5050, 0.7397, 0.9751
# Moxitaidi (SAT), 35, 0.359, 0.572, 0.6164, 0.7400, 0.6726, 0.5067, 0.7394, 0.9729
# Moxitaidi (SAT), 36, 0.389, 0.584, 0.5808, 0.7547, 0.6564, 0.4885, 0.7290, 0.9703
# Moxitaidi (SAT), 37, 0.342, 0.605, 0.5299, 0.8155, 0.6424, 0.4732, 0.7190, 0.9658
# Moxitaidi (SAT), 38, 0.322, 0.553, 0.5866, 0.8216, 0.6845, 0.5203, 0.7455, 0.9715
# Moxitaidi (SAT), 39, 0.292, 0.537, 0.5995, 0.8188, 0.6922, 0.5293, 0.7505, 0.9726
# Moxitaidi (SAT), 40, 0.266, 0.505, 0.6574, 0.7955, 0.7199, 0.5624, 0.7692, 0.9767
# Moxitaidi (SAT), 0.7309, 0.8433, 0.7831, 0.6435, 0.8044, 0.9673
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Moxitaidi (UAV-0.6m), 1, 1.761, 1.753, 0.0000, 0.0000, 0.0000, 0.0000, 0.4593, 0.9186
# Moxitaidi (UAV-0.6m), 2, 1.733, 1.741, 0.0000, 0.0000, 0.0000, 0.0000, 0.4593, 0.9186
# Moxitaidi (UAV-0.6m), 3, 1.704, 1.723, 0.0000, 0.0000, 0.0000, 0.0000, 0.4593, 0.9186
# Moxitaidi (UAV-0.6m), 4, 1.661, 1.683, 0.0000, 0.0000, 0.0000, 0.0000, 0.4593, 0.9186
# Moxitaidi (UAV-0.6m), 5, 1.575, 1.588, 0.0000, 0.0000, 0.0000, 0.0000, 0.4593, 0.9186
# Moxitaidi (UAV-0.6m), 6, 1.465, 2.422, 0.0000, 0.0000, 0.0000, 0.0000, 0.4593, 0.9186
# Moxitaidi (UAV-0.6m), 7, 1.359, 2.101, 0.0000, 0.0000, 0.0000, 0.0000, 0.4593, 0.9186
# Moxitaidi (UAV-0.6m), 8, 1.343, 1.573, 0.0000, 0.0000, 0.0000, 0.0000, 0.4592, 0.9184
# Moxitaidi (UAV-0.6m), 9, 1.314, 1.494, 0.4060, 0.0053, 0.0105, 0.0053, 0.4618, 0.9184
# Moxitaidi (UAV-0.6m), 10, 1.257, 1.409, 0.6743, 0.0302, 0.0578, 0.0297, 0.4747, 0.9199
# Moxitaidi (UAV-0.6m), 11, 1.181, 1.356, 0.7333, 0.0658, 0.1207, 0.0642, 0.4929, 0.9220
# Moxitaidi (UAV-0.6m), 12, 1.230, 1.236, 0.5165, 0.2388, 0.3266, 0.1951, 0.5567, 0.9199
# Moxitaidi (UAV-0.6m), 13, 1.166, 1.320, 0.2324, 0.4295, 0.3016, 0.1776, 0.5049, 0.8381
# Moxitaidi (UAV-0.6m), 14, 1.201, 1.326, 0.3123, 0.3793, 0.3426, 0.2067, 0.5422, 0.8815
# Moxitaidi (UAV-0.6m), 15, 1.142, 1.299, 0.3009, 0.4290, 0.3538, 0.2149, 0.5413, 0.8724
# Moxitaidi (UAV-0.6m), 16, 1.082, 1.335, 0.4376, 0.4275, 0.4325, 0.2759, 0.5907, 0.9087
# Moxitaidi (UAV-0.6m), 17, 1.090, 1.273, 0.2982, 0.4819, 0.3684, 0.2258, 0.5429, 0.8655
# Moxitaidi (UAV-0.6m), 18, 1.052, 1.197, 0.3686, 0.4894, 0.4205, 0.2662, 0.5760, 0.8902
# Moxitaidi (UAV-0.6m), 19, 0.994, 1.128, 0.4448, 0.5609, 0.4961, 0.3299, 0.6164, 0.9073
# Moxitaidi (UAV-0.6m), 20, 1.005, 1.198, 0.2998, 0.6654, 0.4133, 0.2605, 0.5490, 0.8463
# Moxitaidi (UAV-0.6m), 21, 0.952, 1.100, 0.3754, 0.6935, 0.4871, 0.3219, 0.5980, 0.8811
# Moxitaidi (UAV-0.6m), 22, 0.890, 1.189, 0.3125, 0.7480, 0.4409, 0.2828, 0.5592, 0.8456
# Moxitaidi (UAV-0.6m), 23, 0.927, 1.231, 0.2736, 0.7578, 0.4021, 0.2516, 0.5281, 0.8166
# Moxitaidi (UAV-0.6m), 24, 1.036, 1.009, 0.4674, 0.6502, 0.5439, 0.3735, 0.6399, 0.9112
# Moxitaidi (UAV-0.6m), 25, 0.886, 0.991, 0.5657, 0.6195, 0.5914, 0.4198, 0.6732, 0.9303
# Moxitaidi (UAV-0.6m), 26, 0.859, 1.039, 0.3790, 0.7551, 0.5047, 0.3375, 0.6045, 0.8794
# Moxitaidi (UAV-0.6m), 27, 0.795, 1.182, 0.3935, 0.5995, 0.4751, 0.3116, 0.5991, 0.8922
# Moxitaidi (UAV-0.6m), 28, 0.907, 1.034, 0.4780, 0.5664, 0.5185, 0.3500, 0.6301, 0.9144
# Moxitaidi (UAV-0.6m), 29, 0.851, 1.001, 0.5338, 0.5725, 0.5525, 0.3817, 0.6512, 0.9245
# Moxitaidi (UAV-0.6m), 30, 0.829, 0.971, 0.4211, 0.7385, 0.5364, 0.3665, 0.6280, 0.8961
# Moxitaidi (UAV-0.6m), 31, 0.779, 0.960, 0.4407, 0.7634, 0.5588, 0.3877, 0.6415, 0.9019
# Moxitaidi (UAV-0.6m), 32, 0.776, 0.981, 0.4237, 0.7683, 0.5462, 0.3757, 0.6324, 0.8961
# Moxitaidi (UAV-0.6m), 33, 0.747, 1.082, 0.4042, 0.6830, 0.5078, 0.3403, 0.6131, 0.8922
# Moxitaidi (UAV-0.6m), 34, 0.702, 1.050, 0.4643, 0.6742, 0.5499, 0.3792, 0.6421, 0.9102
# Moxitaidi (UAV-0.6m), 35, 0.743, 1.142, 0.5271, 0.5492, 0.5379, 0.3679, 0.6438, 0.9232
# Moxitaidi (UAV-0.6m), 0.5895, 0.4140, 0.4864, 0.3213, 0.6103, 0.9038
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Moxitaidi (UAV-1m), 1, 1.796, 1.799, 0.0000, 0.0000, 0.0000, 0.0000, 0.4569, 0.9138
# Moxitaidi (UAV-1m), 2, 1.778, 1.792, 0.0000, 0.0000, 0.0000, 0.0000, 0.4569, 0.9138
# Moxitaidi (UAV-1m), 3, 1.757, 1.779, 0.0000, 0.0000, 0.0000, 0.0000, 0.4569, 0.9138
# Moxitaidi (UAV-1m), 4, 1.728, 1.752, 0.0000, 0.0000, 0.0000, 0.0000, 0.4569, 0.9138
# Moxitaidi (UAV-1m), 5, 1.662, 1.693, 0.0000, 0.0000, 0.0000, 0.0000, 0.4569, 0.9138
# Moxitaidi (UAV-1m), 6, 1.537, 1.756, 0.0000, 0.0000, 0.0000, 0.0000, 0.4569, 0.9138
# Moxitaidi (UAV-1m), 7, 1.395, 1.580, 0.0000, 0.0000, 0.0000, 0.0000, 0.4569, 0.9138
# Moxitaidi (UAV-1m), 8, 1.316, 1.557, 0.0000, 0.0000, 0.0000, 0.0000, 0.4569, 0.9138
# Moxitaidi (UAV-1m), 9, 1.288, 1.524, 0.1108, 0.0873, 0.0976, 0.0513, 0.4556, 0.8609
# Moxitaidi (UAV-1m), 10, 1.237, 1.457, 0.1557, 0.2442, 0.1901, 0.1051, 0.4610, 0.8207
# Moxitaidi (UAV-1m), 11, 1.332, 1.459, 0.1653, 0.3589, 0.2264, 0.1276, 0.4547, 0.7886
# Moxitaidi (UAV-1m), 12, 1.249, 1.489, 0.1643, 0.4154, 0.2355, 0.1334, 0.4462, 0.7675
# Moxitaidi (UAV-1m), 13, 1.230, 1.544, 0.1765, 0.3813, 0.2413, 0.1372, 0.4618, 0.7934
# Moxitaidi (UAV-1m), 14, 1.193, 1.938, 0.1642, 0.2922, 0.2103, 0.1175, 0.4617, 0.8108
# Moxitaidi (UAV-1m), 15, 1.186, 1.979, 0.1748, 0.2873, 0.2174, 0.1219, 0.4696, 0.8217
# Moxitaidi (UAV-1m), 16, 1.130, 1.666, 0.2113, 0.3491, 0.2632, 0.1516, 0.4890, 0.8316
# Moxitaidi (UAV-1m), 17, 1.099, 1.442, 0.4796, 0.3068, 0.3742, 0.2302, 0.5697, 0.9116
# Moxitaidi (UAV-1m), 18, 1.032, 1.406, 0.2571, 0.4832, 0.3356, 0.2017, 0.5148, 0.8351
# Moxitaidi (UAV-1m), 19, 1.100, 1.501, 0.2773, 0.3849, 0.3223, 0.1921, 0.5239, 0.8605
# Moxitaidi (UAV-1m), 20, 0.980, 1.700, 0.3712, 0.2845, 0.3221, 0.1920, 0.5431, 0.8968
# Moxitaidi (UAV-1m), 21, 1.195, 1.505, 0.2215, 0.6721, 0.3332, 0.1999, 0.4768, 0.7681
# Moxitaidi (UAV-1m), 22, 1.173, 1.518, 0.2137, 0.6082, 0.3163, 0.1878, 0.4743, 0.7733
# Moxitaidi (UAV-1m), 23, 1.099, 1.716, 0.2238, 0.2774, 0.2477, 0.1414, 0.4963, 0.8548
# Moxitaidi (UAV-1m), 24, 1.038, 2.186, 0.2435, 0.2172, 0.2296, 0.1297, 0.5008, 0.8744
# Moxitaidi (UAV-1m), 25, 0.986, 2.019, 0.2065, 0.3394, 0.2568, 0.1473, 0.4864, 0.8306
# Moxitaidi (UAV-1m), 26, 0.979, 1.607, 0.2330, 0.4270, 0.3015, 0.1775, 0.5002, 0.8294
# Moxitaidi (UAV-1m), 27, 0.924, 1.403, 0.2697, 0.6391, 0.3793, 0.2341, 0.5217, 0.8198
# Moxitaidi (UAV-1m), 28, 0.973, 1.338, 0.3076, 0.5675, 0.3989, 0.2492, 0.5471, 0.8526
# Moxitaidi (UAV-1m), 29, 0.910, 1.657, 0.2577, 0.3842, 0.3085, 0.1824, 0.5144, 0.8515
# Moxitaidi (UAV-1m), 30, 0.870, 1.560, 0.2891, 0.4224, 0.3432, 0.2072, 0.5313, 0.8607
# Moxitaidi (UAV-1m), 31, 0.809, 1.450, 0.2938, 0.6209, 0.3989, 0.2491, 0.5394, 0.8387
# Moxitaidi (UAV-1m), 32, 0.772, 1.697, 0.3892, 0.3167, 0.3492, 0.2115, 0.5535, 0.8983
# Moxitaidi (UAV-1m), 33, 1.038, 1.737, 0.2462, 0.4709, 0.3234, 0.1929, 0.5079, 0.8302
# Moxitaidi (UAV-1m), 34, 0.920, 1.604, 0.2220, 0.4994, 0.3073, 0.1816, 0.4894, 0.8060
# Moxitaidi (UAV-1m), 35, 0.939, 1.471, 0.2699, 0.4726, 0.3435, 0.2074, 0.5226, 0.8443
# Moxitaidi (UAV-1m), 36, 0.831, 1.443, 0.3895, 0.4313, 0.4093, 0.2573, 0.5730, 0.8927
# Moxitaidi (UAV-1m), 37, 0.724, 1.283, 0.3812, 0.5898, 0.4631, 0.3013, 0.5885, 0.8821
# Moxitaidi (UAV-1m), 38, 0.733, 1.303, 0.3210, 0.7249, 0.4450, 0.2862, 0.5600, 0.8441
# Moxitaidi (UAV-1m), 39, 0.701, 1.206, 0.3236, 0.6986, 0.4424, 0.2840, 0.5612, 0.8482
# Moxitaidi (UAV-1m), 40, 0.821, 1.454, 0.2797, 0.5790, 0.3772, 0.2324, 0.5295, 0.8352
# Moxitaidi (UAV-1m), 0.4301, 0.7329, 0.5421, 0.3718, 0.6613, 0.9521
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# palu, 1, 1.630, 1.643, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 2, 1.582, 1.620, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 3, 1.515, 1.574, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 4, 1.412, 1.415, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 5, 1.238, 1.487, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 6, 1.179, 1.807, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 7, 1.136, 1.318, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 8, 1.122, 1.159, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 9, 1.107, 1.134, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 10, 1.084, 1.115, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 11, 1.056, 1.122, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 12, 1.026, 1.031, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 13, 1.022, 0.989, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 14, 0.975, 0.984, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 15, 0.958, 0.956, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 16, 0.963, 0.927, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 17, 0.932, 0.918, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 18, 0.971, 0.930, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 19, 0.937, 0.932, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 20, 0.882, 0.961, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 21, 0.872, 0.967, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 22, 0.866, 0.926, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 23, 0.845, 0.884, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 24, 0.821, 0.900, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 25, 0.816, 0.916, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 26, 0.796, 0.927, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 27, 0.796, 0.890, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 28, 0.786, 0.919, 0.0000, 0.0000, 0.0000, 0.0000, 0.4948, 0.9896
# palu, 29, 0.762, 0.900, 0.8571, 0.0001, 0.0003, 0.0001, 0.4949, 0.9896
# palu, 30, 0.738, 0.824, 0.4553, 0.0361, 0.0670, 0.0346, 0.5121, 0.9895
# palu, 31, 0.735, 0.901, 0.2551, 0.1193, 0.1626, 0.0885, 0.5378, 0.9872
# palu, 32, 0.705, 1.041, 0.5438, 0.0847, 0.1465, 0.0791, 0.5344, 0.9897
# palu, 33, 0.666, 0.782, 0.5313, 0.4469, 0.4854, 0.3205, 0.6553, 0.9901
# palu, 34, 0.687, 0.774, 0.5361, 0.4198, 0.4709, 0.3079, 0.6490, 0.9902
# palu, 35, 0.726, 0.976, 0.1751, 0.4036, 0.2443, 0.1391, 0.5565, 0.9739
# palu, 36, 0.699, 1.067, 0.5739, 0.2801, 0.3765, 0.2319, 0.6111, 0.9903
# palu, 37, 0.658, 0.797, 0.4659, 0.4880, 0.4767, 0.3129, 0.6508, 0.9888
# palu, 38, 0.626, 0.727, 0.5007, 0.4722, 0.4860, 0.3210, 0.6553, 0.9896
# palu, 39, 0.679, 0.817, 0.2213, 0.7965, 0.3464, 0.2095, 0.5889, 0.9686
# palu, 40, 0.671, 0.719, 0.5216, 0.4776, 0.4987, 0.3322, 0.6610, 0.9900
# palu, 0.1941, 0.1743, 0.1836, 0.1011, 0.5348, 0.9686
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Tiburon Peninsula (planet), 1, 1.749, 1.730, 0.0000, 0.0000, 0.0000, 0.0000, 0.4770, 0.9539
# Tiburon Peninsula (planet), 2, 1.711, 1.716, 0.0000, 0.0000, 0.0000, 0.0000, 0.4770, 0.9539
# Tiburon Peninsula (planet), 3, 1.674, 1.693, 0.0000, 0.0000, 0.0000, 0.0000, 0.4770, 0.9539
# Tiburon Peninsula (planet), 4, 1.623, 1.643, 0.0000, 0.0000, 0.0000, 0.0000, 0.4770, 0.9539
# Tiburon Peninsula (planet), 5, 1.539, 1.482, 0.0000, 0.0000, 0.0000, 0.0000, 0.4770, 0.9539
# Tiburon Peninsula (planet), 6, 1.341, 3.388, 0.0000, 0.0000, 0.0000, 0.0000, 0.4770, 0.9539
# Tiburon Peninsula (planet), 7, 1.213, 1.937, 0.0000, 0.0000, 0.0000, 0.0000, 0.4769, 0.9539
# Tiburon Peninsula (planet), 8, 1.113, 1.364, 0.1737, 0.0147, 0.0271, 0.0137, 0.4825, 0.9514
# Tiburon Peninsula (planet), 9, 1.024, 1.322, 0.5646, 0.0194, 0.0376, 0.0192, 0.4866, 0.9541
# Tiburon Peninsula (planet), 10, 0.877, 1.230, 0.6856, 0.0445, 0.0836, 0.0436, 0.4993, 0.9550
# Tiburon Peninsula (planet), 11, 0.831, 0.944, 0.8090, 0.3725, 0.5101, 0.3424, 0.6544, 0.9670
# Tiburon Peninsula (planet), 12, 0.849, 0.963, 0.8022, 0.3674, 0.5040, 0.3369, 0.6515, 0.9667
# Tiburon Peninsula (planet), 13, 0.768, 0.765, 0.5583, 0.6530, 0.6019, 0.4305, 0.6948, 0.9602
# Tiburon Peninsula (planet), 14, 0.721, 0.839, 0.7473, 0.5067, 0.6039, 0.4325, 0.7006, 0.9694
# Tiburon Peninsula (planet), 15, 0.713, 0.679, 0.6003, 0.6798, 0.6376, 0.4680, 0.7156, 0.9644
# Tiburon Peninsula (planet), 16, 0.659, 0.683, 0.5441, 0.7410, 0.6275, 0.4571, 0.7076, 0.9595
# Tiburon Peninsula (planet), 17, 0.804, 0.713, 0.4973, 0.7645, 0.6026, 0.4313, 0.6916, 0.9536
# Tiburon Peninsula (planet), 18, 0.801, 1.249, 0.2098, 0.8531, 0.3367, 0.2025, 0.5207, 0.8452
# Tiburon Peninsula (planet), 19, 1.026, 1.169, 0.2213, 0.8016, 0.3468, 0.2098, 0.5327, 0.8609
# Tiburon Peninsula (planet), 20, 0.885, 0.719, 0.6925, 0.6084, 0.6477, 0.4790, 0.7238, 0.9695
# Tiburon Peninsula (planet), 21, 0.680, 1.147, 0.7702, 0.3442, 0.4757, 0.3121, 0.6383, 0.9651
# Tiburon Peninsula (planet), 22, 0.839, 0.650, 0.6492, 0.6805, 0.6645, 0.4975, 0.7324, 0.9683
# Tiburon Peninsula (planet), 23, 0.670, 0.816, 0.3971, 0.7883, 0.5282, 0.3589, 0.6458, 0.9351
# Tiburon Peninsula (planet), 24, 0.702, 0.747, 0.4559, 0.7714, 0.5731, 0.4016, 0.6734, 0.9471
# Tiburon Peninsula (planet), 25, 0.631, 0.631, 0.6472, 0.6845, 0.6653, 0.4985, 0.7329, 0.9683
# Tiburon Peninsula (planet), 26, 0.660, 0.623, 0.6321, 0.7087, 0.6682, 0.5017, 0.7341, 0.9676
# Tiburon Peninsula (planet), 27, 0.645, 0.650, 0.5536, 0.7583, 0.6400, 0.4706, 0.7149, 0.9607
# Tiburon Peninsula (planet), 28, 0.695, 0.605, 0.6325, 0.7271, 0.6765, 0.5112, 0.7390, 0.9680
# Tiburon Peninsula (planet), 29, 0.633, 0.594, 0.6399, 0.7344, 0.6839, 0.5196, 0.7436, 0.9687
# Tiburon Peninsula (planet), 30, 0.597, 0.627, 0.5621, 0.7886, 0.6564, 0.4885, 0.7245, 0.9620
# Tiburon Peninsula (planet), 31, 0.581, 0.599, 0.6110, 0.7591, 0.6771, 0.5118, 0.7386, 0.9666
# Tiburon Peninsula (planet), 32, 0.562, 0.577, 0.6479, 0.7358, 0.6890, 0.5256, 0.7470, 0.9694
# Tiburon Peninsula (planet), 33, 0.569, 0.621, 0.5905, 0.7407, 0.6571, 0.4893, 0.7262, 0.9644
# Tiburon Peninsula (planet), 34, 0.554, 0.587, 0.7271, 0.6528, 0.6880, 0.5243, 0.7481, 0.9727
# Tiburon Peninsula (planet), 35, 0.592, 0.551, 0.6842, 0.7229, 0.7030, 0.5420, 0.7565, 0.9719
# Tiburon Peninsula (planet), 36, 0.532, 0.561, 0.6059, 0.7943, 0.6874, 0.5237, 0.7446, 0.9667
# Tiburon Peninsula (planet), 37, 0.567, 0.563, 0.6456, 0.7545, 0.6958, 0.5335, 0.7510, 0.9696
# Tiburon Peninsula (planet), 38, 0.536, 0.539, 0.6626, 0.7553, 0.7059, 0.5455, 0.7577, 0.9710
# Tiburon Peninsula (planet), 39, 0.506, 0.547, 0.6350, 0.7760, 0.6985, 0.5367, 0.7523, 0.9691
# Tiburon Peninsula (planet), 40, 0.524, 0.523, 0.6884, 0.7413, 0.7139, 0.5551, 0.7634, 0.9726
# Tiburon Peninsula (planet), 0.7044, 0.8586, 0.7739, 0.6312, 0.7966, 0.9642
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Tiburon Peninsula (Sentinel), 1, 1.705, 1.693, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 2, 1.669, 1.673, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 3, 1.629, 1.636, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 4, 1.572, 1.567, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 5, 1.497, 1.363, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 6, 1.357, 1.750, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 7, 1.260, 1.294, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 8, 1.189, 1.232, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 9, 1.104, 1.056, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 10, 1.080, 1.016, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 11, 1.023, 1.007, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 12, 0.986, 0.986, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 13, 0.971, 0.934, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 14, 0.923, 0.888, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 15, 0.889, 0.869, 0.0000, 0.0000, 0.0000, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 16, 0.954, 0.883, 1.0000, 0.0000, 0.0001, 0.0000, 0.4899, 0.9799
# Tiburon Peninsula (Sentinel), 17, 0.918, 0.881, 0.6419, 0.1525, 0.2465, 0.1406, 0.5609, 0.9812
# Tiburon Peninsula (Sentinel), 18, 0.877, 0.894, 0.4242, 0.5379, 0.4743, 0.3109, 0.6433, 0.9760
# Tiburon Peninsula (Sentinel), 19, 0.872, 0.883, 0.3719, 0.6539, 0.4741, 0.3107, 0.6406, 0.9708
# Tiburon Peninsula (Sentinel), 20, 0.823, 0.868, 0.2978, 0.7353, 0.4239, 0.2690, 0.6141, 0.9598
# Tiburon Peninsula (Sentinel), 21, 0.715, 0.778, 0.3809, 0.6933, 0.4917, 0.3260, 0.6484, 0.9711
# Tiburon Peninsula (Sentinel), 22, 0.696, 0.775, 0.3805, 0.6942, 0.4916, 0.3259, 0.6483, 0.9711
# Tiburon Peninsula (Sentinel), 23, 0.808, 0.829, 0.3214, 0.7112, 0.4427, 0.2843, 0.6239, 0.9640
# Tiburon Peninsula (Sentinel), 24, 0.746, 0.790, 0.4475, 0.6122, 0.5171, 0.3487, 0.6627, 0.9770
# Tiburon Peninsula (Sentinel), 25, 0.731, 0.738, 0.3826, 0.6889, 0.4919, 0.3262, 0.6486, 0.9714
# Tiburon Peninsula (Sentinel), 26, 0.730, 0.830, 0.2841, 0.7689, 0.4150, 0.2618, 0.6087, 0.9564
# Tiburon Peninsula (Sentinel), 27, 0.674, 0.813, 0.3049, 0.7129, 0.4271, 0.2715, 0.6162, 0.9615
# Tiburon Peninsula (Sentinel), 28, 0.647, 0.813, 0.2909, 0.7259, 0.4153, 0.2621, 0.6102, 0.9589
# Tiburon Peninsula (Sentinel), 29, 0.672, 0.718, 0.4394, 0.6111, 0.5112, 0.3434, 0.6598, 0.9765
# Tiburon Peninsula (Sentinel), 30, 0.635, 0.740, 0.3790, 0.7099, 0.4942, 0.3282, 0.6492, 0.9707
# Tiburon Peninsula (Sentinel), 31, 0.600, 0.753, 0.3580, 0.7306, 0.4805, 0.3163, 0.6420, 0.9682
# Tiburon Peninsula (Sentinel), 32, 0.581, 0.706, 0.4139, 0.6762, 0.5135, 0.3454, 0.6596, 0.9742
# Tiburon Peninsula (Sentinel), 33, 0.704, 0.776, 0.4210, 0.6024, 0.4956, 0.3295, 0.6522, 0.9753
# Tiburon Peninsula (Sentinel), 34, 0.668, 0.749, 0.4981, 0.5181, 0.5079, 0.3404, 0.6600, 0.9798
# Tiburon Peninsula (Sentinel), 0.6558, 0.5861, 0.6190, 0.4482, 0.7080, 0.9686
# region, epoch, train_loss, val_loss, precision, recall, f1, iou, miou, oa
# Wenchuan, 1, 1.664, 1.668, 0.0000, 0.0000, 0.0000, 0.0000, 0.4798, 0.9595
# Wenchuan, 2, 1.623, 1.650, 0.0000, 0.0000, 0.0000, 0.0000, 0.4798, 0.9595
# Wenchuan, 3, 1.581, 1.620, 0.0000, 0.0000, 0.0000, 0.0000, 0.4798, 0.9595
# Wenchuan, 4, 1.513, 1.548, 0.0000, 0.0000, 0.0000, 0.0000, 0.4798, 0.9595
# Wenchuan, 5, 1.370, 1.403, 0.0000, 0.0000, 0.0000, 0.0000, 0.4798, 0.9595
# Wenchuan, 6, 1.107, 2.245, 0.4573, 0.0006, 0.0011, 0.0006, 0.4800, 0.9595
# Wenchuan, 7, 0.963, 1.576, 0.7471, 0.1288, 0.2198, 0.1234, 0.5431, 0.9630
# Wenchuan, 8, 0.909, 1.038, 0.6797, 0.3334, 0.4473, 0.2881, 0.6272, 0.9666
# Wenchuan, 9, 0.818, 0.892, 0.6368, 0.4205, 0.5065, 0.3391, 0.6527, 0.9668
# Wenchuan, 10, 0.909, 0.801, 0.5638, 0.5656, 0.5647, 0.3934, 0.6786, 0.9647
# Wenchuan, 11, 0.853, 0.821, 0.4632, 0.7126, 0.5614, 0.3903, 0.6719, 0.9549
# Wenchuan, 12, 0.862, 0.760, 0.5292, 0.6152, 0.5689, 0.3976, 0.6794, 0.9623
# Wenchuan, 13, 0.814, 0.849, 0.6368, 0.4724, 0.5425, 0.3722, 0.6696, 0.9677
# Wenchuan, 14, 0.775, 0.733, 0.6018, 0.5667, 0.5837, 0.4121, 0.6893, 0.9673
# Wenchuan, 15, 0.764, 0.713, 0.5728, 0.6312, 0.6006, 0.4292, 0.6971, 0.9660
# Wenchuan, 16, 0.754, 0.720, 0.6013, 0.5764, 0.5886, 0.4170, 0.6918, 0.9674
# Wenchuan, 17, 0.772, 0.696, 0.5834, 0.6179, 0.6001, 0.4287, 0.6972, 0.9667
# Wenchuan, 18, 0.735, 0.696, 0.6072, 0.5895, 0.5982, 0.4268, 0.6970, 0.9679
# Wenchuan, 19, 0.724, 0.686, 0.6215, 0.5862, 0.6033, 0.4319, 0.7000, 0.9688
# Wenchuan, 20, 0.716, 0.671, 0.6071, 0.6151, 0.6111, 0.4400, 0.7037, 0.9683
# Wenchuan, 21, 0.729, 0.668, 0.5512, 0.6901, 0.6129, 0.4418, 0.7028, 0.9647
# Wenchuan, 22, 0.721, 0.675, 0.6412, 0.5924, 0.6158, 0.4449, 0.7071, 0.9701
# Wenchuan, 23, 0.738, 0.649, 0.5840, 0.6729, 0.6253, 0.4549, 0.7106, 0.9673
# Wenchuan, 24, 0.706, 0.647, 0.6259, 0.6250, 0.6255, 0.4550, 0.7120, 0.9697
# Wenchuan, 25, 0.683, 0.649, 0.6461, 0.6034, 0.6240, 0.4535, 0.7116, 0.9706
# Wenchuan, 26, 0.643, 0.702, 0.6405, 0.5629, 0.5992, 0.4277, 0.6983, 0.9695
# Wenchuan, 27, 0.687, 0.645, 0.5905, 0.6566, 0.6218, 0.4512, 0.7090, 0.9677
# Wenchuan, 28, 0.681, 0.637, 0.5675, 0.7045, 0.6287, 0.4584, 0.7119, 0.9663
# Wenchuan, 29, 0.700, 0.631, 0.6267, 0.6419, 0.6342, 0.4644, 0.7168, 0.9700
# Wenchuan, 30, 0.666, 0.647, 0.5665, 0.6826, 0.6192, 0.4484, 0.7067, 0.9660
# Wenchuan, 31, 0.698, 0.715, 0.6398, 0.5447, 0.5884, 0.4169, 0.6927, 0.9691
# Wenchuan, 32, 0.633, 0.689, 0.7041, 0.5282, 0.6036, 0.4323, 0.7018, 0.9719
# Wenchuan, 33, 0.657, 0.615, 0.5804, 0.7086, 0.6381, 0.4686, 0.7175, 0.9675
# Wenchuan, 34, 0.628, 0.593, 0.6414, 0.6711, 0.6559, 0.4880, 0.7294, 0.9715
# Wenchuan, 35, 0.590, 0.659, 0.7099, 0.5607, 0.6265, 0.4561, 0.7142, 0.9729
# Wenchuan, 36, 0.592, 0.630, 0.6529, 0.6242, 0.6382, 0.4687, 0.7196, 0.9713
# Wenchuan, 37, 0.612, 0.626, 0.6833, 0.6069, 0.6429, 0.4737, 0.7228, 0.9727
# Wenchuan, 38, 0.630, 0.600, 0.6342, 0.6632, 0.6484, 0.4797, 0.7249, 0.9709
# Wenchuan, 39, 0.552, 0.688, 0.7024, 0.5549, 0.6200, 0.4493, 0.7106, 0.9725
# Wenchuan, 40, 0.535, 0.628, 0.5730, 0.7114, 0.6347, 0.4649, 0.7154, 0.9668
# Wenchuan, 0.7143, 0.6342, 0.6719, 0.5059, 0.7346, 0.9647
